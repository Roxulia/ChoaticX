# %%
# !pip install ta
# Out:
# Collecting ta
#   Downloading ta-0.11.0.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from ta) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from ta) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->ta) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->ta) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->ta) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->ta) (1.17.0)
# Building wheels for collected packages: ta
#   Building wheel for ta (setup.py) ... done
#   Created wheel for ta: filename=ta-0.11.0-py3-none-any.whl size=29412 sha256=09dc9605a88b95b4c89f2df27f53352e514fbfa5183fc95fc4c0f691a4d83d39
#   Stored in directory: /root/.cache/pip/wheels/a1/d7/29/7781cc5eb9a3659d032d7d15bdd0f49d07d2b24fec29f44bc4
# Successfully built ta
# Installing collected packages: ta
# Successfully installed ta-0.11.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import ta

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/OHLC.csv')

# %%
from binance.client import Client
import pandas as pd

# Set up Binance API client with your credentials
api_key = 'HFj6VrsLhvgnJTWCknFKNFM4RCtJESHBKJG4pmknxRTLV9VT2D63HGwQroG01B7b'
api_secret = 'mTAfE3M9Oh4sH7GQFEF9EPE0PXTEYuK6MQS2HSUb3sJqtW6bO3QLOdVX4Ti0Olh6'

client = Client(api_key, api_secret)

# Fetch historical data (15-min candles)
symbol = 'BTCUSDT'
interval = Client.KLINE_INTERVAL_1HOUR
lookback = '3 years'  # Lookback period (can be adjusted)

# Get historical data (OHLCV data)
klines = client.get_historical_klines(symbol, interval,lookback)

# Convert to DataFrame
df = pd.DataFrame(klines, columns=['timestamp', 'open', 'high', 'low', 'close', 'volume', 'close_time', 'quote_asset_volume', 'number_of_trades', 'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'ignore'])

# Convert timestamp to datetime
df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')

# Set 'timestamp' as index
df.set_index('timestamp', inplace=True)

# Keep relevant columns
df = df[['open', 'high', 'low', 'close', 'volume']]

# Convert columns to numeric
df = df.apply(pd.to_numeric)
df = df.astype({
    'open': 'float32',
    'high': 'float32',
    'low': 'float32',
    'close': 'float32',
    'volume': 'float32'
})

# %%
df.to_csv('OHLC.csv')

# %%
df_4h = df.resample('4h').agg({
    'open': 'first',
    'high': 'max',
    'low': 'min',
    'close': 'last',
    'volume': 'sum'
})

df_1d = df.resample('1D').agg({
    'open': 'first',
    'high': 'max',
    'low': 'min',
    'close': 'last',
    'volume': 'sum'
})

# %%
# Indicators
df['ema20'] = ta.trend.ema_indicator(df['close'], window=20)
df['ema50'] = ta.trend.ema_indicator(df['close'], window=50)
df['atr'] = ta.volatility.average_true_range(df['high'], df['low'], df['close'], window=14)
df['rsi'] = ta.momentum.rsi(df['close'], window=5)  # Faster RSI for quicker signal
df['atr_mean'] = df['atr'].rolling(window=50).mean()

# %%
df.iloc[26219]
# Out:
# open        103226.250000
# high        103226.250000
# low         103034.500000
# close       103152.480000
# volume         291.549300
# ema20       102927.779621
# ema50       101721.856623
# atr            506.122554
# rsi             56.927441
# atr_mean       656.063581
# Name: 26219, dtype: float64

# %%
df_1h.tail(5)

# %% [markdown]
# No RSI just ema and atr and only short position

# %%
# Indicators
df['ema50'] = ta.trend.ema_indicator(df['close'], window=50)
df['ema200'] = ta.trend.ema_indicator(df['close'], window=200)
df['atr'] = ta.volatility.average_true_range(df['high'], df['low'], df['close'], window=14)
df['atr_mean'] = df['atr'].rolling(window=50).mean()
# Strategy parameters
risk_multiple = 2  # Risk-to-reward ratio

# Store trades
trades = []

# Strategy logic (Backtesting)
for i in range(200, len(df) - 12):  # reserve space for next 11 candles
    row = df.iloc[i]

    if row['atr'] < row['atr_mean']:
        continue

    # === SHORT SETUP ===
    if row['close'] < row['ema50'] and row['close'] < row['ema200']:
        candle_body = abs(row['close'] - row['open'])
        upper_wick = row['high'] - max(row['close'], row['open'])
        if upper_wick > 1.5 * candle_body:
            entry_price = row['close']
            sl = row['high']
            risk = sl - entry_price
            tp = entry_price - risk_multiple * risk

            next_candles = df.iloc[i + 1:i + 96]
            hit_tp = any(next_candles['low'] <= tp)
            hit_sl = any(next_candles['high'] >= sl)

            if hit_tp and not hit_sl:
                trades.append({'type': 'short', 'entry': entry_price, 'exit': tp, 'pnl': risk_multiple})
            elif hit_sl and not hit_tp:
                trades.append({'type': 'short', 'entry': entry_price, 'exit': sl, 'pnl': -1})
            elif hit_tp and hit_sl:
                first_tp = next_candles[next_candles['low'] <= tp].index[0]
                first_sl = next_candles[next_candles['high'] >= sl].index[0]
                if first_tp < first_sl:
                    trades.append({'type': 'short', 'entry': entry_price, 'exit': tp, 'pnl': risk_multiple})
                else:
                    trades.append({'type': 'short', 'entry': entry_price, 'exit': sl, 'pnl': -1})

    # === LONG SETUP ===
    if row['close'] > row['ema50'] and row['close'] > row['ema200']:
        candle_body = abs(row['close'] - row['open'])
        lower_wick = min(row['close'], row['open']) - row['low']
        if lower_wick > 1.5 * candle_body:
            entry_price = row['close']
            sl = row['low']
            risk = entry_price - sl
            tp = entry_price + risk_multiple * risk

            next_candles = df.iloc[i + 1:i + 12]
            hit_tp = any(next_candles['high'] >= tp)
            hit_sl = any(next_candles['low'] <= sl)

            if hit_tp and not hit_sl:
                trades.append({'type': 'long', 'entry': entry_price, 'exit': tp, 'pnl': risk_multiple})
            elif hit_sl and not hit_tp:
                trades.append({'type': 'long', 'entry': entry_price, 'exit': sl, 'pnl': -1})
            elif hit_tp and hit_sl:
                first_tp = next_candles[next_candles['high'] >= tp].index[0]
                first_sl = next_candles[next_candles['low'] <= sl].index[0]
                if first_tp < first_sl:
                    trades.append({'type': 'long', 'entry': entry_price, 'exit': tp, 'pnl': risk_multiple})
                else:
                    trades.append({'type': 'long', 'entry': entry_price, 'exit': sl, 'pnl': -1})

# Analyze results
if len(trades) == 0:
    print("No Trade entered")
else:
    trade_df = pd.DataFrame(trades)
    win_rate = (trade_df['pnl'] > 0).mean()
    avg_r = trade_df['pnl'].mean()
    net_pnl = trade_df['pnl'].sum()
    total_trades = len(trades)
    long_trades = trade_df[trade_df['type'] == 'long'].shape[0]
    short_trades = trade_df[trade_df['type'] == 'short'].shape[0]

    print(f"Win Rate: {win_rate:.2f}")
    print(f"Average R-Multiple: {avg_r:.2f}")
    print(f"Net PnL (R): {net_pnl:.2f}")
    print(f"Total Trades: {total_trades}")
    print(f"Long Trades: {long_trades}, Short Trades: {short_trades}")

# %% [markdown]
# ChatGPT provided strategy for Short include RSI,EMA,Atr

# %%
# Indicators
df['ema50'] = ta.trend.ema_indicator(df['close'], window=50)
df['ema200'] = ta.trend.ema_indicator(df['close'], window=200)
df['atr'] = ta.volatility.average_true_range(df['high'], df['low'], df['close'], window=14)
df['rsi'] = ta.momentum.rsi(df['close'], window=5)  # Faster RSI for quicker signal
df['atr_mean'] = df['atr'].rolling(window=50).mean()
# Strategy parameters
risk_multiple = 5
rsi_overbought = 65
rsi_oversold = 35

# Trade storage
trades = []

# Strategy logic
for i in range(200, len(df)-1):
    row = df.iloc[i]
    if row['atr'] < row['atr_mean']:
        continue

    # ---------- SHORT ENTRY ----------
    if row['close'] < row['ema50'] and row['close'] < row['ema200']:
        candle_body = abs(row['close'] - row['open'])
        upper_wick = row['high'] - max(row['close'], row['open'])
        if upper_wick > 1.5 * candle_body:
            if row['rsi'] > rsi_overbought:
                entry_price = row['close']
                sl = row['high']
                risk = sl - entry_price
                tp = entry_price - risk_multiple * risk

                next_candles = df.iloc[i+1:i+96]
                hit_tp = any(next_candles['low'] <= tp)
                hit_sl = any(next_candles['high'] >= sl)

                if hit_tp and not hit_sl:
                    trades.append({'type': 'short', 'entry': entry_price, 'exit': tp, 'pnl': risk_multiple})
                elif hit_sl and not hit_tp:
                    trades.append({'type': 'short', 'entry': entry_price, 'exit': sl, 'pnl': -1})
                elif hit_tp and hit_sl:
                    first_tp = next_candles[next_candles['low'] <= tp].index[0]
                    first_sl = next_candles[next_candles['high'] >= sl].index[0]
                    if first_tp < first_sl:
                        trades.append({'type': 'short', 'entry': entry_price, 'exit': tp, 'pnl': risk_multiple})
                    else:
                        trades.append({'type': 'short', 'entry': entry_price, 'exit': sl, 'pnl': -1})

    # ---------- LONG ENTRY ----------
    if row['close'] > row['ema50'] and row['close'] > row['ema200']:
        candle_body = abs(row['close'] - row['open'])
        lower_wick = min(row['close'], row['open']) - row['low']
        if lower_wick > 1.5 * candle_body:
            if row['rsi'] < rsi_oversold:
                entry_price = row['close']
                sl = row['low']
                risk = entry_price - sl
                tp = entry_price + risk_multiple * risk

                next_candles = df.iloc[i+1:i+96]
                hit_tp = any(next_candles['high'] >= tp)
                hit_sl = any(next_candles['low'] <= sl)

                if hit_tp and not hit_sl:
                    trades.append({'type': 'long', 'entry': entry_price, 'exit': tp, 'pnl': risk_multiple})
                elif hit_sl and not hit_tp:
                    trades.append({'type': 'long', 'entry': entry_price, 'exit': sl, 'pnl': -1})
                elif hit_tp and hit_sl:
                    first_tp = next_candles[next_candles['high'] >= tp].index[0]
                    first_sl = next_candles[next_candles['low'] <= sl].index[0]
                    if first_tp < first_sl:
                        trades.append({'type': 'long', 'entry': entry_price, 'exit': tp, 'pnl': risk_multiple})
                    else:
                        trades.append({'type': 'long', 'entry': entry_price, 'exit': sl, 'pnl': -1})

# Results
if len(trades) == 0:
    print("No Trade entered")
else:
    trade_df = pd.DataFrame(trades)
    win_rate = (trade_df['pnl'] > 0).mean()
    avg_r = trade_df['pnl'].mean()
    net_pnl = trade_df['pnl'].sum()
    long_count = trade_df[trade_df['type'] == 'long'].shape[0]
    short_count = trade_df[trade_df['type'] == 'short'].shape[0]

    print(f"Win Rate: {win_rate:.2f}")
    print(f"Average Risk/Reward: {avg_r:.2f}")
    print(f"Net PnL: {net_pnl:.2f}")
    print(f"Total Trades: {len(trades)} | Long: {long_count}, Short: {short_count}")

# %% [markdown]
# Strategy with Liquidity Sweep

# %%
# Indicators
df['ema50'] = ta.trend.ema_indicator(df['close'], window=50)
df['ema200'] = ta.trend.ema_indicator(df['close'], window=200)
df['atr'] = ta.volatility.average_true_range(df['high'], df['low'], df['close'], window=14)
df['atr_mean'] = df['atr'].rolling(window=50).mean()

# Strategy parameters
risk_multiple = 2  # Risk-to-reward ratio
swing_lookback = 20  # For finding liquidity zones
trades = []

# Strategy logic
for i in range(200, len(df) - 12):
    row = df.iloc[i]
    prev_data = df.iloc[i - swing_lookback:i]

    if row['atr'] < row['atr_mean']:
        continue

    swing_high = prev_data['high'].max()
    swing_low = prev_data['low'].min()

    # === SHORT SETUP (Buy-side Liquidity Sweep) ===
    if row['high'] > swing_high and row['close'] < swing_high:
        if row['close'] < row['ema50'] and row['close'] < row['ema200']:
            candle_body = abs(row['close'] - row['open'])
            upper_wick = row['high'] - max(row['close'], row['open'])

            if upper_wick > 1.5 * candle_body:
                entry_price = row['close']
                sl = row['high']
                risk = sl - entry_price
                tp = entry_price - risk_multiple * risk

                next_candles = df.iloc[i + 1:i + 192]
                hit_tp = any(next_candles['low'] <= tp)
                hit_sl = any(next_candles['high'] >= sl)

                if hit_tp and not hit_sl:
                    trades.append({'type': 'short', 'entry': entry_price, 'exit': tp, 'pnl': risk_multiple})
                elif hit_sl and not hit_tp:
                    trades.append({'type': 'short', 'entry': entry_price, 'exit': sl, 'pnl': -1})
                elif hit_tp and hit_sl:
                    first_tp = next_candles[next_candles['low'] <= tp].index[0]
                    first_sl = next_candles[next_candles['high'] >= sl].index[0]
                    if first_tp < first_sl:
                        trades.append({'type': 'short', 'entry': entry_price, 'exit': tp, 'pnl': risk_multiple})
                    else:
                        trades.append({'type': 'short', 'entry': entry_price, 'exit': sl, 'pnl': -1})

    # === LONG SETUP (Sell-side Liquidity Sweep) ===
    if row['low'] < swing_low and row['close'] > swing_low:
        if row['close'] > row['ema50'] and row['close'] > row['ema200']:
            candle_body = abs(row['close'] - row['open'])
            lower_wick = min(row['close'], row['open']) - row['low']

            if lower_wick > 1.5 * candle_body:
                entry_price = row['close']
                sl = row['low']
                risk = entry_price - sl
                tp = entry_price + risk_multiple * risk

                next_candles = df.iloc[i + 1:i + 12]
                hit_tp = any(next_candles['high'] >= tp)
                hit_sl = any(next_candles['low'] <= sl)

                if hit_tp and not hit_sl:
                    trades.append({'type': 'long', 'entry': entry_price, 'exit': tp, 'pnl': risk_multiple})
                elif hit_sl and not hit_tp:
                    trades.append({'type': 'long', 'entry': entry_price, 'exit': sl, 'pnl': -1})
                elif hit_tp and hit_sl:
                    first_tp = next_candles[next_candles['high'] >= tp].index[0]
                    first_sl = next_candles[next_candles['low'] <= sl].index[0]
                    if first_tp < first_sl:
                        trades.append({'type': 'long', 'entry': entry_price, 'exit': tp, 'pnl': risk_multiple})
                    else:
                        trades.append({'type': 'long', 'entry': entry_price, 'exit': sl, 'pnl': -1})

# Analyze results
if len(trades) == 0:
    print("No Trade entered")
else:
    trade_df = pd.DataFrame(trades)
    win_rate = (trade_df['pnl'] > 0).mean()
    avg_r = trade_df['pnl'].mean()
    net_pnl = trade_df['pnl'].sum()
    total_trades = len(trades)
    long_trades = trade_df[trade_df['type'] == 'long'].shape[0]
    short_trades = trade_df[trade_df['type'] == 'short'].shape[0]

    print(f"Win Rate: {win_rate:.2f}")
    print(f"Average R-Multiple: {avg_r:.2f}")
    print(f"Net PnL (R): {net_pnl:.2f}")
    print(f"Total Trades: {total_trades}")
    print(f"Long Trades: {long_trades}, Short Trades: {short_trades}")

# %%
import pandas as pd

def detect_liquidity_zones(df, window=10):
    df = df.copy()
    df['support'] = df['low'].rolling(window).min()
    df['resistance'] = df['high'].rolling(window).max()
    df.dropna(subset=['support', 'resistance'], inplace=True)
    return df

def detect_sweep_and_entry(df, wick_ratio=1.5):
    df = df.copy()
    df['signal'] = None

    for i in range(20, len(df) - 1):
        row = df.iloc[i]
        prev_support = df['support'].iloc[i - 1]
        prev_resistance = df['resistance'].iloc[i - 1]
        next_row = df.iloc[i + 1]

        if pd.isna(prev_support) or pd.isna(prev_resistance):
            continue  # Skip rows where rolling values aren't available

        # Sell-side (support sweep)
        if row['low'] < prev_support:
            if row['close'] > row['open']:  # bullish recovery
                wick = min(row['close'], row['open']) - row['low']
                body = abs(row['close'] - row['open'])
                if wick > wick_ratio * body and next_row['close'] > next_row['open']:
                    df.at[df.index[i + 1], 'signal'] = 'long'

        # Buy-side (resistance sweep)
        elif row['high'] > prev_resistance:
            if row['close'] < row['open']:  # bearish rejection
                wick = row['high'] - max(row['close'], row['open'])
                body = abs(row['close'] - row['open'])
                if wick > wick_ratio * body and next_row['close'] < next_row['open']:
                    df.at[df.index[i + 1], 'signal'] = 'short'

    return df


def backtest_trades(df, lookahead=10):
    df = df.copy()
    trades = []

    for i in range(len(df) - lookahead):
        row = df.iloc[i]

        if row['signal'] in ['long', 'short']:
            entry = row['open']
            sl = df.iloc[i - 1]['low'] if row['signal'] == 'long' else df.iloc[i - 1]['high']
            tp = df.iloc[i - 1]['resistance'] if row['signal'] == 'long' else df.iloc[i - 1]['support']

            outcome = None
            pnl = 0

            for j in range(1, lookahead + 1):
                next_row = df.iloc[i + j]

                if row['signal'] == 'long':
                    if next_row['low'] <= sl:
                        outcome = 'loss'
                        pnl = sl - entry
                        break
                    elif next_row['high'] >= tp:
                        outcome = 'win'
                        pnl = tp - entry
                        break
                elif row['signal'] == 'short':
                    if next_row['high'] >= sl:
                        outcome = 'loss'
                        pnl = entry - sl
                        break
                    elif next_row['low'] <= tp:
                        outcome = 'win'
                        pnl = entry - tp
                        break

            if outcome is None:
                outcome = 'timeout'
                last_row = df.iloc[i + lookahead]
                pnl = last_row['close'] - entry if row['signal'] == 'long' else entry - last_row['close']

            trades.append({
                'index': i,
                'side': row['signal'],
                'entry': entry,
                'sl': sl,
                'tp': tp,
                'outcome': outcome,
                'pnl': pnl
            })

    return pd.DataFrame(trades)

# %%
df = detect_liquidity_zones(df, window=50)

# Step 2: Detect entry signals

# %%
df.isna().sum()

# %%
df = detect_sweep_and_entry(df, wick_ratio=1.5)

# %%
df.tail(10)

# %%
  # Make sure columns are named: ['Open', 'High', 'Low', 'Close', 'Volume']

results = backtest_trades(df, lookahead=96)

# Step 4: Evaluate
if len(results) > 0:
    total = len(results)
    wins = (results['outcome'] == 'win').sum()
    timeouts = (results['outcome'] == 'timeout').sum()
    winrate = wins/(total - timeouts)
    print(f"\nTotal Trades: {total}")
    print(f"Winning Trades: {wins}")
    print(f"Win Rate: {winrate}")
    print(f"Average PnL: {results['pnl'].mean():.2f}")
    print(f"Net PNL : {results['pnl'].sum()} ")
    print("Timeout trades:",timeouts )
else:
    print("No trades found.")

# %% [markdown]
# SMC Structure Detection (FVG)

# %%
def detect_fvg(df,threshold = 300,timeframe = '1h'):
    """
    Detect Fair Value Gaps (FVGs)
    """

    fvg_indices = []

    highs = df['high'].values
    lows = df['low'].values
    opens = df['open'].values
    closes = df['close'].values
    volumes = df['volume'].values
    ema20 = df['ema20'].values
    ema50 = df['ema50'].values
    atr = df['atr'].values
    rsi = df['rsi'].values
    atr_mean = df['atr_mean'].values

    length = len(df)

    close_rolling = df['close'].rolling(window=5)
    volume_rolling = df['volume'].rolling(window=5)

    avg_volume_past_5 = volume_rolling.mean().values
    prev_volatility_5 = close_rolling.std().values
    momentum_5 = closes - np.roll(closes, 5)

    for i in range(5, length - 1):
        prev_high = highs[i - 1]
        prev_low = lows[i - 1]
        next_high = highs[i + 1]
        next_low = lows[i + 1]

        body = abs(opens[i] - closes[i])
        candle_range = highs[i] - lows[i]
        body_ratio = body / candle_range if candle_range != 0 else 0
        wick_ratio = 1 - body_ratio
        body_size = body
        volume_on_creation = volumes[i]

        if next_low > prev_high:
            gap = next_low - prev_high
            if gap >= threshold:
                # Touch index search — can be optimized further with precomputed conditions if needed
                touch_indx = next(
                    (j for j in range(i + 2, length) if opens[j] > next_low and lows[j] < next_low), None
                )
                fvg_indices.append({
                    'index': i,
                    'type': 'Bullish FVG',
                    'ema 20': ema20[i],
                    'ema 50': ema50[i],
                    'atr': atr[i],
                    'rsi': rsi[i],
                    'atr_mean': atr_mean[i],
                    'zone_high': next_low,
                    'zone_low': prev_high,
                    'zone_width': gap,
                    'body_size': body_size,
                    'wick_ratio': wick_ratio,
                    'volume_on_creation': volume_on_creation,
                    'avg_volume_past_5': avg_volume_past_5[i],
                    'prev_volatility_5': prev_volatility_5[i],
                    'momentum_5': momentum_5[i],
                    'touch_index': touch_indx,
                    'time_frame': timeframe,
                })

        elif next_high < prev_low:
            gap = prev_low - next_high
            if gap >= threshold:
                touch_indx = next(
                    (j for j in range(i + 2, length) if opens[j] < next_high and highs[j] > next_high), None
                )
                fvg_indices.append({
                    'index': i,
                    'type': 'Bearish FVG',
                    'ema 20': ema20[i],
                    'ema 50': ema50[i],
                    'atr': atr[i],
                    'rsi': rsi[i],
                    'atr_mean': atr_mean[i],
                    'zone_high': prev_low,
                    'zone_low': next_high,
                    'zone_width': gap,
                    'body_size': body_size,
                    'wick_ratio': wick_ratio,
                    'volume_on_creation': volume_on_creation,
                    'avg_volume_past_5': avg_volume_past_5[i],
                    'prev_volatility_5': prev_volatility_5[i],
                    'momentum_5': momentum_5[i],
                    'touch_index': touch_indx,
                    'time_frame': timeframe,
                })

    return fvg_indices

# %%
def check_fvg_reactions(df, fvg_list, lookahead=24, N=24):
    results = []

    for fvg in fvg_list:
        idx = fvg['index']
        high = fvg['zone_high']
        low = fvg['zone_low']
        direction = fvg['type']
        entered = False
        bounced = False
        violated = False
        partial_mitigated = False
        time_to_entry = None
        price_retrace_ratio = None
        volume_on_entry = None
        bounce_candles = None
        violated_candles = None
        max_price_move = None  # NEW
        reaction_type = 'no entry'

        for j in range(idx + 2, min(idx + 2 + lookahead, len(df))):
            candle = df.iloc[j]

            wick_enters = candle['low'] <= high and candle['high'] >= low
            close_inside = low <= candle['close'] <= high

            if wick_enters:
                entered = True
                entry_price = candle['low'] if direction == 'Bullish FVG' else candle['high']
                price_retrace_ratio = (entry_price - low) / (high - low) if direction == 'Bullish FVG' else (high - entry_price) / (high - low)
                volume_on_entry = candle['volume']
                if time_to_entry is None:
                    time_to_entry = j - idx

                if not close_inside:
                    partial_mitigated = True
                    reaction_type = 'partial mitigate'

                if direction == 'Bullish FVG':
                    if candle['close'] > high:
                        bounced = True
                        bounce_candles = j - idx - time_to_entry


                        for k in range(j+1,min(j +N, len(df))):
                            # Check if price reverses (violation)
                            if df.iloc[k]['close'] < low:
                                violated = True
                                violated_candles = k-j
                                # Look ahead for max price movement after bounce
                                max_high = df.iloc[j : k]['high'].max()
                                max_price_move = max_high - high
                                reaction_type = 'bounce + break'
                                break
                        if not violated:
                            # Look ahead for max price movement after bounce
                            max_high = df.iloc[j : j + N]['high'].max()
                            max_price_move = max_high - high
                            reaction_type = 'clean bounce'
                        break

                    elif candle['close'] < low:
                        violated = True
                        violated_candles = j-time_to_entry-idx
                        reaction_type = 'violation'
                        break

                elif direction == 'Bearish FVG':
                    if candle['close'] < low:
                        bounced = True
                        bounce_candles = j - idx -time_to_entry
                        for k in range(j+1,min(j +N, len(df))):
                            # Check if price reverses (violation)
                            if df.iloc[k]['close'] > high:
                                violated = True
                                violated_candles = k-j
                                min_low = df.iloc[j : k]['low'].min()
                                max_price_move = low - min_low
                                reaction_type = 'bounce + break'
                                break
                        if not violated:
                            min_low = df.iloc[j : j+N]['low'].min()
                            max_price_move = low - min_low
                            reaction_type = 'clean bounce'
                        break

                    elif candle['close'] > high:
                        violated = True
                        violated_candles = j-time_to_entry-idx
                        reaction_type = 'violation'
                        break


        results.append({
            **fvg,
            'entered': entered,
            'partial_mitigated': partial_mitigated and not close_inside,
            'bounced': bounced,
            'violated': violated,
            'time_to_entry' : time_to_entry,
            'price_retrace_ratio' : price_retrace_ratio,
            'volume_on_entry' : volume_on_entry,
            'bounce_after_candles': bounce_candles,
            'violated_after_candles' : violated_candles,
            'max_price_move': max_price_move,  # NEW
            'reaction_type' : reaction_type
        })

    return results

# %%
fvg = detect_fvg(df)

# %%
fvg
# Out:
# [{'index': 52,
#   'type': 'Bullish FVG',
#   'ema 20': np.float64(30105.78612520125),
#   'ema 50': np.float64(29892.465527938813),
#   'atr': np.float64(407.9155378479372),
#   'rsi': np.float64(82.92445470664134),
#   'atr_mean': np.float64(323.98816015953673),
#   'zone_high': np.float64(30858.01),
#   'zone_low': np.float64(30500.0),
#   'zone_width': np.float64(358.0099999999984),
#   'body_size': np.float64(600.3099999999977),
#   'wick_ratio': np.float64(0.272157423797863),
#   'volume_on_creation': np.float64(5900.3486),
#   'avg_volume_past_5': np.float64(1608.6229600000001),
#   'prev_volatility_5': 198.8063113937783,
#   'momentum_5': np.float64(1044.7199999999975),
#   'touch_index': 57},
#  {'index': 62,
#   'type': 'Bearish FVG',
#   'ema 20': np.float64(30357.970604424223),
#   'ema 50': np.float64(30121.20790426041),
#   'atr': np.float64(412.3728269253151),
#   'rsi': np.float64(13.64482317098333),
#   'atr_mean': np.float64(403.0846649994186),
#   'zone_high': np.float64(30250.01),
#   'zone_low': np.float64(29741.28),
#   'zone_width': np.float64(508.72999999999956),
#   'body_size': np.float64(712.8099999999977),
#   'wick_ratio': np.float64(0.2209045599615278),
#   'volume_on_creation': np.float64(6918.515),
#   'avg_volume_past_5': np.float64(2141.7354800000003),
#   'prev_volatility_5': 202.45785467598003,
#   'momentum_5': np.float64(-1197.75),
#   'touch_index': 64},
#  {'index': 166,
#   'type': 'Bearish FVG',
#   'ema 20': np.float64(30110.77461058224),
#   'ema 50': np.float64(29943.006613830377),
#   'atr': np.float64(356.02596768700784),
#   'rsi': np.float64(20.091038414670336),
#   'atr_mean': np.float64(336.95977874858477),
#   'zone_high': np.float64(30103.06),
#   'zone_low': np.float64(29491.84),
#   'zone_width': np.float64(611.2200000000012),
#   'body_size': np.float64(873.2199999999975),
#   'wick_ratio': np.float64(0.09725108292239482),
#   'volume_on_creation': np.float64(5657.1987),
#   'avg_volume_past_5': np.float64(2334.57786),
#   'prev_volatility_5': 72.96029742263944,
#   'momentum_5': np.float64(-812.4799999999996),
#   'touch_index': 183},
#  {'index': 209,
#   'type': 'Bullish FVG',
#   'ema 20': np.float64(29489.282297534068),
#   'ema 50': np.float64(29502.7122613749),
#   'atr': np.float64(191.09614463922202),
#   'rsi': np.float64(91.71873695565702),
#   'atr_mean': np.float64(256.7836367525608),
#   'zone_high': np.float64(30102.11),
#   'zone_low': np.float64(29594.07),
#   'zone_width': np.float64(508.0400000000009),
#   'body_size': np.float64(585.75),
#   'wick_ratio': np.float64(0.11630257679077927),
#   'volume_on_creation': np.float64(4570.0747),
#   'avg_volume_past_5': np.float64(669.1608679999999),
#   'prev_volatility_5': 98.78609072131613,
#   'momentum_5': np.float64(854.6800000000003),
#   'touch_index': 211},
#  {'index': 243,
#   'type': 'Bearish FVG',
#   'ema 20': np.float64

#   'type': 'Bullish FVG',
#   'ema 20': np.float64(99930.42142540262),
#   'ema 50': np.float64(98295.40244111794),
#   'atr': np.float64(693.4764332195539),
#   'rsi': np.float64(89.57633550976061),
#   'atr_mean': np.float64(537.0946370933136),
#   'zone_high': np.float64(102114.66),
#   'zone_low': np.float64(101365.39),
#   'zone_width': np.float64(749.2700000000041),
#   'body_size': np.float64(1307.800000000003),
#   'wick_ratio': np.float64(0.16449986903384783),
#   'volume_on_creation': np.float64(2318.7505),
#   'avg_volume_past_5': np.float64(2058.8617719999997),
#   'prev_volatility_5': 251.733207443914,
#   'momentum_5': np.float64(1849.7200000000012),
#   'touch_index': 26281},
#  {'index': 26277,
#   'type': 'Bearish FVG',
#   'ema 20': np.float64(104056.65946201973),
#   'ema 50': np.float64(103824.37081434423),
#   'atr': np.float64(717.5398380697383),
#   'rsi': np.float64(24.00590390264054),
#   'atr_mean': np.float64(529.9281668250485),
#   'zone_high': np.float64(103675.57),
#   'zone_low': np.float64(103206.35),
#   'zone_width': np.float64(469.22000000000116),
#   'body_size': np.float64(1520.0099999999948),
#   'wick_ratio': np.float64(0.18091876599757795),
#   'volume_on_creation': np.float64(3039.4553),
#   'avg_volume_past_5': np.float64(1231.18988),
#   'prev_volatility_5': 346.8541597703583,
#   'momentum_5': np.float64(-1659.3499999999913),
#   'touch_index': 26296},
#  {'index': 26281,
#   'type': 'Bearish FVG',
#   'ema 20': np.float64(103494.8343136341),
#   'ema 50': np.float64(103610.39047196125),
#   'atr': np.float64(796.3282794957777),
#   'rsi': np.float64(18.149486363147517),
#   'atr_mean': np.float64(553.5025326189664),
#   'zone_high': np.float64(102529.52),
#   'zone_low': np.float64(102122.02),
#   'zone_width': np.float64(407.5),
#   'body_size': np.float64(925.6100000000006),
#   'wick_ratio': np.float64(0.5234145311687435),
#   'volume_on_creation': np.float64(3108.2017),
#   'avg_volume_past_5': np.float64(1597.37772),
#   'prev_volatility_5': 745.4594112827363,
#   'momentum_5': np.float64(-2689.4000000000087),
#   'touch_index': 26283},
#  {'index': 26296,
#   'type': 'Bullish FVG',
#   'ema 20': np.float64(102797.92402336992),
#   'ema 50': np.float64(103130.61325277487),
#   'atr': np.float64(686.54022866331),
#   'rsi': np.float64(75.60627550186999),
#   'atr_mean': np.float64(630.9504022425516),
#   'zone_high': np.float64(103273.84),
#   'zone_low': np.float64(102958.81),
#   'zone_width': np.float64(315.02999999999884),
#   'body_size': np.float64(735.0299999999988),
#   'wick_ratio': np.float64(0.06863912823111817),
#   'volume_on_creation': np.float64(997.6213),
#   'avg_volume_past_5': np.float64(824.3582700000001),
#   'prev_volatility_5': 114.59670880963736,
#   'momentum_5': np.float64(711.3199999999924),
#   'touch_index': 26301}]

# %% [markdown]
# SMC Structure Detection (OB)

# %%
def detect_order_blocks(df, min_body_ratio=0.3, timeframe='1h'):
    """
    Optimized detection of bullish and bearish Order Blocks (OB).
    """
    ob_list = []

    highs = df['high'].values
    lows = df['low'].values
    opens = df['open'].values
    closes = df['close'].values
    volumes = df['volume'].values
    ema20 = df['ema20'].values
    ema50 = df['ema50'].values
    atr = df['atr'].values
    rsi = df['rsi'].values
    atr_mean = df['atr_mean'].values

    for i in range(5, len(df) - 2):
        open_, close_ = opens[i], closes[i]
        high_, low_ = highs[i], lows[i]
        prev_close = closes[i - 1]
        next_close = closes[i + 1]
        next2_close = closes[i + 2]

        body = abs(open_ - close_)
        candle_range = high_ - low_
        if candle_range == 0:
            continue

        body_ratio = body / candle_range
        if body_ratio < min_body_ratio:
            continue

        wick_ratio = 1 - body_ratio
        zone_high, zone_low = high_, low_
        zone_width = zone_high - zone_low
        body_size = body
        volume_on_creation = volumes[i]

        avg_volume_past_5 = volumes[i-5:i].mean()
        prev_volatility_5 = closes[i-5:i].std()
        momentum_5 = close_ - closes[i - 5]

        # --- Bullish OB Detection ---
        if close_ < open_:
            if (prev_close > low_ and
                next_close > high_ and
                next2_close > closes[i + 1]):

                # Delay touch check until required
                touch_indx = next(
                    (j for j in range(i + 3, len(df))
                     if opens[j] > zone_high and lows[j] < zone_high),
                    None
                )

                ob_list.append({
                    'index': i,
                    'type': 'Bullish OB',
                    'ema 20': ema20[i],
                    'ema 50': ema50[i],
                    'atr': atr[i],
                    'rsi': rsi[i],
                    'atr_mean': atr_mean[i],
                    'zone_high': zone_high,
                    'zone_low': zone_low,
                    'zone_width': zone_width,
                    'body_size': body_size,
                    'wick_ratio': wick_ratio,
                    'volume_on_creation': volume_on_creation,
                    'avg_volume_past_5': avg_volume_past_5,
                    'prev_volatility_5': prev_volatility_5,
                    'momentum_5': momentum_5,
                    'touch_index': touch_indx,
                    'time_frame': timeframe,
                })

        # --- Bearish OB Detection ---
        elif close_ > open_:
            if (prev_close < high_ and
                next_close < low_ and
                next2_close < closes[i + 1]):

                touch_indx = next(
                    (j for j in range(i + 3, len(df))
                     if opens[j] < zone_low and highs[j] > zone_low),
                    None
                )

                ob_list.append({
                    'index': i,
                    'type': 'Bearish OB',
                    'ema 20': ema20[i],
                    'ema 50': ema50[i],
                    'atr': atr[i],
                    'rsi': rsi[i],
                    'atr_mean': atr_mean[i],
                    'zone_high': zone_high,
                    'zone_low': zone_low,
                    'zone_width': zone_width,
                    'body_size': body_size,
                    'wick_ratio': wick_ratio,
                    'volume_on_creation': volume_on_creation,
                    'avg_volume_past_5': avg_volume_past_5,
                    'prev_volatility_5': prev_volatility_5,
                    'momentum_5': momentum_5,
                    'touch_index': touch_indx,
                    'time_frame': timeframe,
                })

    return ob_list

# %%
def check_ob_reactions(df, ob_list, lookahead=24, N=24):
    results = []

    for ob in ob_list:
        idx = ob['index']
        high = ob['zone_high']
        low = ob['zone_low']
        direction = ob['type']
        entered = False
        bounced = False
        violated = False
        partial_mitigated = False
        time_to_entry = None
        price_retrace_ratio = None
        volume_on_entry = None
        bounce_candles = None
        violated_candles = None
        max_price_move = None  # NEW
        reaction_type = 'no entry'

        for j in range(idx + 2, min(idx + 2 + lookahead, len(df))):
            candle = df.iloc[j]

            wick_enters = candle['low'] <= high and candle['high'] >= low
            close_inside = low <= candle['close'] <= high

            if wick_enters:
                entered = True
                entry_price = candle['low'] if direction == 'Bullish OB' else candle['high']
                price_retrace_ratio = (entry_price - low) / (high - low) if direction == 'Bullish OB' else (high - entry_price) / (high - low)
                volume_on_entry = candle['volume']
                if time_to_entry is None:
                    time_to_entry = j - idx

                if not close_inside:
                    partial_mitigated = True
                    reaction_type = 'partial mitigate'

                if direction == 'Bullish OB':
                    if candle['close'] > high:
                        bounced = True
                        bounce_candles = j - time_to_entry -idx


                        for k in range(j+1,min(j +N, len(df))):
                            # Check if price reverses (violation)
                            if df.iloc[k]['close'] < low:
                                violated = True
                                violated_candles = k-j
                                # Look ahead for max price movement after bounce
                                max_high = df.iloc[j : k]['high'].max()
                                max_price_move = max_high - high
                                reaction_type = 'bounce + break'
                                break
                        if not violated:
                            # Look ahead for max price movement after bounce
                            max_high = df.iloc[j : j + N]['high'].max()
                            max_price_move = max_high - high
                            reaction_type = 'clean bounce'
                        break

                    elif candle['close'] < low:
                        violated = True
                        violated_candles = j-time_to_entry-idx
                        reaction_type = 'violation'
                        break

                elif direction == 'Bearish OB':
                    if candle['close'] < low:
                        bounced = True
                        bounce_candles = j - time_to_entry - idx
                        for k in range(j+1,min(j +N, len(df))):
                            # Check if price reverses (violation)
                            if df.iloc[k]['close'] > high:
                                violated = True
                                violated_candles = k-j
                                min_low = df.iloc[j : k]['low'].min()
                                max_price_move = low - min_low
                                reaction_type = 'bounce + break'
                                break
                        if not violated:
                            min_low = df.iloc[j : j+N]['low'].min()
                            max_price_move = low - min_low
                            reaction_type = 'clean bounce'
                        break

                    elif candle['close'] > high:
                        violated = True
                        violated_candles = j-time_to_entry-idx
                        reaction_type = 'violation'
                        break


        results.append({
            **ob,
            'entered': entered,
            'partial_mitigated': partial_mitigated and not close_inside,
            'bounced': bounced,
            'violated': violated,
            'time_to_entry' : time_to_entry,
            'price_retrace_ratio' : price_retrace_ratio,
            'volume_on_entry' : volume_on_entry,
            'bounce_after_candles': bounce_candles,
            'violated_after_candle' : violated_candles,
            'max_price_move': max_price_move,  # NEW
            'reaction_type' : reaction_type
        })

    return results

# %%
obs = detect_order_blocks(df)
obs
# Out:
# [{'index': 23,
#   'type': 'Bullish OB',
#   'ema 20': np.float64(29344.168161119782),
#   'ema 50': np.float64(nan),
#   'atr': np.float64(386.23002882926045),
#   'rsi': np.float64(24.13877916021832),
#   'atr_mean': np.float64(nan),
#   'zone_high': np.float64(29098.08),
#   'zone_low': np.float64(28768.0),
#   'zone_width': np.float64(330.08000000000175),
#   'body_size': np.float64(124.66999999999825),
#   'wick_ratio': np.float64(0.622303683955412),
#   'volume_on_creation': np.float64(1633.8505),
#   'avg_volume_past_5': np.float64(2917.6626399999996),
#   'prev_volatility_5': np.float64(163.92451950821712),
#   'momentum_5': np.float64(-503.119999999999),
#   'touch_index': 72,
#   'time_frame': '1h'},
#  {'index': 36,
#   'type': 'Bullish OB',
#   'ema 20': np.float64(29646.128769284038),
#   'ema 50': np.float64(nan),
#   'atr': np.float64(405.4079214136062),
#   'rsi': np.float64(39.00772209306894),
#   'atr_mean': np.float64(nan),
#   'zone_high': np.float64(29799.0),
#   'zone_low': np.float64(29480.0),
#   'zone_width': np.float64(319.0),
#   'body_size': np.float64(107.54000000000087),
#   'wick_ratio': np.float64(0.6628840125391822),
#   'volume_on_creation': np.float64(1111.1659),
#   'avg_volume_past_5': np.float64(1619.74198),
#   'prev_volatility_5': np.float64(121.55493530087526),
#   'momentum_5': np.float64(-472.6200000000026),
#   'touch_index': 38,
#   'time_frame': '1h'},
#  {'index': 49,
#   'type': 'Bullish OB',
#   'ema 20': np.float64(

#   'type': 'Bearish OB',
#   'ema 20': np.float64(19834.220668405655),
#   'ema 50': np.float64(20449.144430874116),
#   'atr': np.float64(327.4251468066859),
#   'rsi': np.float64(31.586468575333),
#   'atr_mean': np.float64(390.2020314814061),
#   'zone_high': np.float64(19233.71),
#   'zone_low': np.float64(19090.92),
#   'zone_width': np.float64(142.79000000000087),
#   'body_size': np.float64(44.650000000001455),
#   'wick_ratio': np.float64(0.6873030324252316),
#   'volume_on_creation': np.float64(3893.65),
#   'avg_volume_past_5': np.float64(8227.49056),
#   'prev_volatility_5': np.float64(125.8404242523048),
#   'momentum_5': np.float64(191.22999999999956),
#   'touch_index': 863,
#   'time_frame': '1h'},
#  {'index': 868,
#   'type': 'Bullish OB',
#   'ema 20': np.float64(19125.80695015623),
#   'ema 50': np.float64(19968.535718610165),
#   'atr': np.float64(347.7810079066987),
#   'rsi': np.float64(5.050245394372439),
#   'atr_mean': np.float64(365.6522451917275),
#   'zone_high': np.float64(18177.41),
#   'zone_low': np.float64(17622.0),
#   'zone_width': np.float64(555.4099999999999),
#   'body_size': np.float64(258.6100000000006),
#   'wick_ratio': np.float64(0.53438000756198),
#   'volume_on_creation': np.float64(23329.137),
#   'avg_volume_past_5': np.float64(9465.814139999999),
#   'prev_volatility_5': np.float64(351.63265699306174),
#   'momentum_5': np.float64(-1144.7599999999984),
#   'touch_index': 877,
#   'time_frame': '1h'},
#  {'index': 982,
#   'type': 'Bearish OB',
#   'ema 20': np.float64(20475.295579871465),
#   'ema 50': np.float64(20463.485725016155),
#   'atr': np.float64(271.06712817284864),
#   'rsi': np.float64(57.39433010227964),
#   'atr_mean': np.float64(326.30466860898173),
#   'zone_high': np.float64(20615.94),
#   'zone_low': np.float64(20397.59),
#   'zone_width': np.float64(218.34999999999854),
#   'body_size': np.float64(149.77000000000044),
#   'wick_ratio': np.float64(0.3140828944355327),
#   'volume_on_creation': np.float64(3297.5781),
#   'avg_volume_past_5': np.float64(3948.0973599999998),
#   'prev_volatility_5': np.float64(101.44660191450573),
#   'momentum_5': np.float64(-136.69000000000233),
#   'touch_index': 986,
#   'time_frame': '1h'},
#  {'index': 989,
#   'type': 'Bullish OB',
#   'ema 20': np.float64(20528.22927252521),
#   'ema 50': np.float64(20486.58977417723),
#   'atr': np.float64(277.72271893224575),
#   'rsi': np.float64(56.48317810505389),
#   'atr_mean': np.float64(312.73432823689126),
#   'zone_high': np.float64(20852.44),
#   'zone_low': np.float64(20672.72),
#   'zone_width': np.float64(179.71999999999753),
#   'body_size': np.float64(127.5),
#   'wick_ratio': np.float64(0.29056309815267223),
#   'volume_on_creation': np.float64(1717.5364),
#   'avg_volume_past_5': np.float64(3617.7707200000004),
#   'prev_volatility_5': np.float64(259.9002022007686),
#   'momentum_5': np.float64(403.47999999999956),
#   'touch_index': 998,
#   'time_frame': '1h'},
#  {'index': 1058,
#   'type': 'Bullish OB',
#   'ema 20': np.float64(

#   'type': 'Bullish OB',
#   'ema 20': np.float64(23847.23360216256),
#   'ema 50': np.float64(23793.131113638894),
#   'atr': np.float64(201.21754789348205),
#   'rsi': np.float64(28.12325033980494),
#   'atr_mean': np.float64(257.53938518154644),
#   'zone_high': np.float64(23747.0),
#   'zone_low': np.float64(23574.96),
#   'zone_width': np.float64(172.04000000000087),
#   'body_size': np.float64(116.91999999999825),
#   'wick_ratio': np.float64(0.32039060683563325),
#   'volume_on_creation': np.float64(4803.6045),
#   'avg_volume_past_5': np.float64(3689.7606800000003),
#   'prev_volatility_5': np.float64(36.07828288596931),
#   'momentum_5': np.float64(-141.22000000000116),
#   'touch_index': 1890,
#   'time_frame': '1h'},
#  {'index': 1925,
#   'type': 'Bullish OB',
#   'ema 20': np.float64(23217.634134401847),
#   'ema 50': np.float64(23426.008510516047),
#   'atr': np.float64(212.8603080330311),
#   'rsi': np.float64(40.69045650647168),
#   'atr_mean': np.float64(211.7966167375932),
#   'zone_high': np.float64(23132.37),
#   'zone_low': np.float64(22981.8),
#   'zone_width': np.float64(150.5699999999997),
#   'body_size': np.float64(96.81999999999971),
#   'wick_ratio': np.float64(0.3569768214119685),
#   'volume_on_creation': np.float64(2774.4023),
#   'avg_volume_past_5': np.float64(6600.07064),
#   'prev_volatility_5': np.float64(102.22889755837124),
#   'momentum_5': np.float64(-179.84999999999854),
#   'touch_index': 1929,
#   'time_frame': '1h'},
#  {'index': 1937,
#   'type': 'Bullish OB',
#   'ema 20': np.float64(22996.583229097483),
#   'ema 50': np.float64(23236.473482958005),
#   'atr': np.float64(195.96129208236613),
#   'rsi': np.float64(18.899548164891314),
#   'atr_mean': np.float64(206.81557746875976),
#   'zone_high': np.float64(22845.0),
#   'zone_low': np.float64(22654.37),
#   'zone_width': np.float64(190.63000000000102),
#   'body_size': np.float64(98.65999999999985),
#   'wick_ratio': np.float64(0.48245291926769485),
#   'volume_on_creation': np.float64(6028.103),
#   'avg_volume_past_5': np.float64(4894.38516),
#   'prev_volatility_5': np.float64(26.601931809550354),
#   'momentum_5': np.float64(-151.1999999999971),
#   'touch_index': 1939,
#   'time_frame': '1h'},
#  {'index': 1956,
#   'type': 'Bullish OB',
#   'ema 20': np.float64(22938.022608932493),
#   'ema 50': np.float64(23080.635521589556),
#   'atr': np.float64(208.42600096473254),
#   'rsi': np.float64(40.09782836633944),
#   'atr_mean': np.float64(215.1238062974335),
#   'zone_high': np.float64(22901.94),
#   'zone_low': np.float64(22822.4),
#   'zone_width': np.float64(79.53999999999724),
#   'body_size': np.float64(32.090000000000146),
#   'wick_ratio': np.float64(0.5965551923560315),
#   'volume_on_creation': np.float64(3692.981),
#   'avg_volume_past_5': np.float64(5234.57094),
#   'prev_volatility_5': np.float64(77.33052608123181),
#   'momentum_5': np.float64(-156.22999999999956),
#   'touch_index': 1974,
#   'time_frame': '1h'},
#  {'index': 1959,
#   'type': 'Bullish OB',
#   'ema 20': np.float64

#   'type': 'Bearish OB',
#   'ema 20': np.float64(23130.20040251499),
#   'ema 50': np.float64(23099.827133485785),
#   'atr': np.float64(112.64179575875778),
#   'rsi': np.float64(73.35148286404849),
#   'atr_mean': np.float64(135.63143168680253),
#   'zone_high': np.float64(23402.0),
#   'zone_low': np.float64(23262.02),
#   'zone_width': np.float64(139.97999999999956),
#   'body_size': np.float64(47.330000000001746),
#   'wick_ratio': np.float64(0.6618802686097879),
#   'volume_on_creation': np.float64(3759.2478),
#   'avg_volume_past_5': np.float64(3812.6481),
#   'prev_volatility_5': np.float64(61.096998158665166),
#   'momentum_5': np.float64(217.63999999999942),
#   'touch_index': 2072,
#   'time_frame': '1h'},
#  {'index': 2073,
#   'type': 'Bullish OB',
#   'ema 20': np.float64(23161.827661499872),
#   'ema 50': np.float64(23118.473557419216),
#   'atr': np.float64(123.27541828055725),
#   'rsi': np.float64(51.81867891082949),
#   'atr_mean': np.float64(128.14840047914325),
#   'zone_high': np.float64(23275.15),
#   'zone_low': np.float64(23162.98),
#   'zone_width': np.float64(112.17000000000189),
#   'body_size': np.float64(42.80999999999767),
#   'wick_ratio': np.float64(0.618347151644852),
# ...
#   'body_size': np.float64(106.92999999999302),
#   'wick_ratio': np.float64(0.6979463856953346),
#   'volume_on_creation': np.float64(469.52484),
#   'avg_volume_past_5': np.float64(986.7981299999999),
#   'prev_volatility_5': np.float64(267.04686277880415),
#   'momentum_5': np.float64(320.6900000000023),
#   'touch_index': 25783,
#   'time_frame': '1h'},
#  {'index': 25799,
#   'type': 'Bullish OB',
#   'ema 20': np.float64(88939.73310681735),
#   'ema 50': np.float64(87703.4533214504),
#   'atr': np.float64(629.850473385551),
#   'rsi': np.float64(81.15521888537886),
#   'atr_mean': np.float64(487.4103480591205),
#   'zone_high': np.float64(91041.97),
#   'zone_low': np.float64(90624.03),
#   'zone_width': np.float64(417.9400000000023),
#   'body_size': np.float64(261.50999999999476),
#   'wick_ratio': np.float64(0.37428817533618863),
#   'volume_on_creation': np.float64(1828.9598),
#   'avg_volume_past_5': np.float64(3225.17819),
#   'prev_volatility_5': np.float64(944.9802783762194),
#   'momentum_5': np.float64(2059.0),
#   'touch_index': 25802,
#   'time_frame': '1h'},
#  {'index': 25819,
#   'type': 'Bearish OB',
#   'ema 20': np.float64(92798.21415324743),
#   'ema 50': np.float64(90723.85605497236),
#   'atr': np.float64(670.5534603302477),
#   'rsi': np.float64(55.86092738661974),
#   'atr_mean': np.float64(637.7704604910862),
#   'zone_high': np.float64(93857.14),
#   'zone_low': np.float64(93421.94),
#   'zone_width': np.float64(435.1999999999971),
#   'body_size': np.float64(265.3899999999994),
#   'wick_ratio': np.float64(0.39018841911764435),
#   'volume_on_creation': np.float64(715.7846),
#   'avg_volume_past_5': np.float64(1102.81056),
#   'prev_volatility_5': np.float64(288.3826513089884),
#   'momentum_5': np.float64(-402.4200000000128),
#   'touch_index': 25821,
#   'time_frame': '1h'},
#  {'index': 25874,
#   'type': 'Bearish OB',
#   'ema 20': np.float64(94315.3351395162),
#   'ema 50': np.float64(93497.96904746136),
#   'atr': np.float64(661.0270889705959),
#   'rsi': np.float64(65.77901019917681),
#   'atr_mean': np.float64(601.938444036428),
#   'zone_high': np.float64(95318.26),
#   'zone_low': np.float64(94879.05),
#   'zone_width': np.float64(439.20999999999185),
#   'body_size': np.float64(320.8399999999965),
#   'wick_ratio': np.float64(0.26950661414812405),
#   'volume_on_creation': np.float64(754.0757),
#   'avg_volume_past_5': np.float64(1981.324266),
#   'prev_volatility_5': np.float64(285.8593090735393),
#   'momentum_5': np.float64(-77.0),
#   'touch_index': 25876,
#   'time_frame': '1h'},
#  {'index': 25928,
#   'type': 'Bullish OB',
#   'ema 20': np.float64(93935.47979080828),
#   'ema 50': np.float64(94035.05431570654),
#   'atr': np.float64(387.6021879407568),
#   'rsi': np.float64(13.191567627316388),
#   'atr_mean': np.float64(405.9355047792808),
#   'zone_high': np.float64(93598.2),
#   'zone_low': np.float64(92800.01),
#   'zone_width': np.float64(798.1900000000023),
#   'body_size': np.float64(469.90999999998894),
#   'wick_ratio': np.float64(0.41128052218145106),
#   'volume_on_creation': np.float64(1271.6218),
#   'avg_volume_past_5': np.float64(413.524),
#   'prev_volatility_5': np.float64(334.84028530629354),
#   'momentum_5': np.float64(-1310.8699999999953),
#   'touch_index': 25930,
#   'time_frame': '1h'},
#  {'index': 25941,
#   'type': 'Bearish OB',
#   'ema 20': np.float64(94417.01165258652),
#   'ema 50': np.float64(94242.97707681998),
#   'atr': np.float64(558.176095715476),
#   'rsi': np.float64(44.887775532477214),
#   'atr_mean': np.float64(385.77070105092287),
#   'zone_high': np.float64(94900.0),
#   'zone_low': np.float64(93850.0),
#   'zone_width': np.float64(1050.0),
#   'body_size': np.float64(452.02999999999884),
#   'wick_ratio': np.float64(0.5694952380952392),
#   'volume_on_creation': np.float64(1173.2566),
#   'avg_volume_past_5': np.float64(1715.8844199999999),
#   'prev_volatility_5': np.float64(510.5607596202457),
#   'momentum_5': np.float64(-321.34000000001106),
#   'touch_index': 25943,
#   'time_frame': '1h'},
#  {'index': 25956,
#   'type': 'Bullish OB',
#   'ema 20': np.float64(94518.7120825279),
#   'ema 50': np.float64(94366.94511279452),
#   'atr': np.float64(502.48514164620383),
#   'rsi': np.float64(31.52087512634226),
#   'atr_mean': np.float64(435.1566349649838),
#   'zone_high': np.float64(94417.97),
#   'zone_low': np.float64(94200.0),
#   'zone_width': np.float64(217.97000000000116),
#   'body_size': np.float64(76.83000000000175),
#   'wick_ratio': np.float64(0.6475203009588415),
#   'volume_on_creation': np.float64(1647.4596),
#   'avg_volume_past_5': np.float64(613.0250680000001),
#   'prev_volatility_5': np.float64(239.46291626053556),
#   'momentum_5': np.float64(-788.7799999999988),
#   'touch_index': 25972,
#   'time_frame': '1h'},
#  {'index': 25986,
#   'type': 'Bearish OB',
#   'ema 20': np.float64(94837.03262993212),
#   'ema 50': np.float64(94706.6177884756),
#   'atr': np.float64(398.45472452824157),
#   'rsi': np.float64(71.93118178029665),
#   'atr_mean': np.float64(493.1060656894478),
#   'zone_high': np.float64(95228.45),
#   'zone_low': np.float64(94928.44),
#   'zone_width': np.float64(300.00999999999476),
#   'body_size': np.float64(230.13999999999942),
#   'wick_ratio': np.float64(0.23289223692542438),
#   'volume_on_creation': np.float64(619.85077),
#   'avg_volume_past_5': np.float64(360.127172),
#   'prev_volatility_5': np.float64(135.20631337330232),
#   'momentum_5': np.float64(424.66999999999825),
#   'touch_index': 26001,
#   'time_frame': '1h'},
#  {'index': 26012,
#   'type': 'Bullish OB',
#   'ema 20': np.float64(95211.86127045883),
#   'ema 50': np.float64(94855.79659259126),
#   'atr': np.float64(504.71097282229215),
#   'rsi': np.float64(56.47166566558061),
#   'atr_mean': np.float64(490.57117938377115),
#   'zone_high': np.float64(96734.89),
#   'zone_low': np.float64(95769.66),
#   'zone_width': np.float64(965.2299999999959),
#   'body_size': np.float64(563.679999999993),
#   'wick_ratio': np.float64(0.4160148358422393),
#   'volume_on_creation': np.float64(1740.493),
#   'avg_volume_past_5': np.float64(1011.851772),
#   'prev_volatility_5': np.float64(445.82129929378266),
#   'momentum_5': np.float64(599.3600000000006),
#   'touch_index': 26016,
#   'time_frame': '1h'},
#  {'index': 26026,
#   'type': 'Bearish OB',
#   'ema 20': np.float64(96400.1435143158),
#   'ema 50': np.float64(95676.76917169518),
#   'atr': np.float64(478.9491933300305),
#   'rsi': np.float64(73.2074979174062),
#   'atr_mean': np.float64(505.3164480237247),
#   'zone_high': np.float64(97233.1),
#   'zone_low': np.float64(96952.58),
#   'zone_width': np.float64(280.5200000000041),
#   'body_size': np.float64(149.73000000001048),
#   'wick_ratio': np.float64(0.46624126621984774),
#   'volume_on_creation': np.float64(434.57257),
#   'avg_volume_past_5': np.float64(474.830006),
#   'prev_volatility_5': np.float64(277.31027354932075),
#   'momentum_5': np.float64(729.9900000000052),
#   'touch_index': 26028,
#   'time_frame': '1h'},
#  {'index': 26043,
#   'type': 'Bearish OB',
#   'ema 20': np.float64(96944.57319624076),
#   'ema 50': np.float64(96338.70787038273),
#   'atr': np.float64(480.26573173614304),
#   'rsi': np.float64(45.15971862845797),
#   'atr_mean': np.float64(499.1540256223346),
#   'zone_high': np.float64(97136.0),
#   'zone_low': np.float64(96844.05),
#   'zone_width': np.float64(291.9499999999971),
#   'body_size': np.float64(98.08000000000175),
#   'wick_ratio': np.float64(0.66405206370953),
#   'volume_on_creation': np.float64(243.50865),
#   'avg_volume_past_5': np.float64(657.52608),
#   'prev_volatility_5': np.float64(173.62776072967392),
#   'momentum_5': np.float64(-307.88000000000466),
#   'touch_index': 26046,
#   'time_frame': '1h'},
#  {'index': 26098,
#   'type': 'Bullish OB',
#   'ema 20': np.float64(95051.99902771687),
#   'ema 50': np.float64(95566.55472135983),
#   'atr': np.float64(441.71254745807397),
#   'rsi': np.float64(30.43918748336867),
#   'atr_mean': np.float64(326.17557264615857),
#   'zone_high': np.float64(94299.25),
#   'zone_low': np.float64(94016.6),
#   'zone_width': np.float64(282.6499999999942),
#   'body_size': np.float64(205.19000000000233),
#   'wick_ratio': np.float64(0.27404917742789114),
#   'volume_on_creation': np.float64(708.8673),
#   'avg_volume_past_5': np.float64(1170.8416080000002),
#   'prev_volatility_5': np.float64(384.98368903630467),
#   'momentum_5': np.float64(-984.3500000000058),
#   'touch_index': 26100,
#   'time_frame': '1h'},
#  {'index': 26110,
#   'type': 'Bullish OB',
#   'ema 20': np.float64(94490.76069399738),
#   'ema 50': np.float64(95086.40574232304),
#   'atr': np.float64(451.5712325843259),
#   'rsi': np.float64(25.479974298190257),
#   'atr_mean': np.float64(340.6055278590705),
#   'zone_high': np.float64(93977.13),
#   'zone_low': np.float64(93613.66),
#   'zone_width': np.float64(363.47000000000116),
#   'body_size': np.float64(109.05999999999767),
#   'wick_ratio': np.float64(0.6999477260846911),
#   'volume_on_creation': np.float64(718.83),
#   'avg_volume_past_5': np.float64(968.57986),
#   'prev_volatility_5': np.float64(155.8378196716093),
#   'momentum_5': np.float64(-351.58000000000175),
#   'touch_index': 26115,
#   'time_frame': '1h'},
#  {'index': 26113,
#   'type': 'Bearish OB',
#   'ema 20': np.float64(94492.20250514286),
#   'ema 50': np.float64(95018.49016274708),
#   'atr': np.float64(463.6404475174068),
#   'rsi': np.float64(69.20827040239463),
#   'atr_mean': np.float64(349.6114012778344),
#   'zone_high': np.float64(94900.0),
#   'zone_low': np.float64(94443.56),
#   'zone_width': np.float64(456.4400000000023),
#   'body_size': np.float64(230.38000000000466),
#   'wick_ratio': np.float64(0.49526772412583586),
#   'volume_on_creation': np.float64(448.44052),
#   'avg_volume_past_5': np.float64(1032.2759979999998),
#   'prev_volatility_5': np.float64(262.0266589948452),
#   'momentum_5': np.float64(504.00999999999476),
#   'touch_index': 26116,
#   'time_frame': '1h'},
#  {'index': 26132,
#   'type': 'Bullish OB',
#   'ema 20': np.float64(94243.5459316147),
#   'ema 50': np.float64(94629.17650775479),
#   'atr': np.float64(404.8730923726368),
#   'rsi': np.float64(21.325973548879332),
#   'atr_mean': np.float64(401.5761315470647),
#   'zone_high': np.float64(94019.86),
#   'zone_low': np.float64(93377.0),
#   'zone_width': np.float64(642.8600000000006),
#   'body_size': np.float64(319.08000000000175),
#   'wick_ratio': np.float64(0.5036555393087119),
#   'volume_on_creation': np.float64(1216.743),
#   'avg_volume_past_5': np.float64(711.755782),
#   'prev_volatility_5': np.float64(206.46647694964904),
#   'momentum_5': np.float64(-758.9799999999959),
#   'touch_index': None,
#   'time_frame': '1h'},
#  {'index': 26162,
#   'type': 'Bullish OB',
#   'ema 20': np.float64(96484.89588062128),
#   'ema 50': np.float64(95882.05686930087),
#   'atr': np.float64(532.1065002166999),
#   'rsi': np.float64(27.246710361384103),
#   'atr_mean': np.float64(476.5274352485308),
#   'zone_high': np.float64(96625.0),
#   'zone_low': np.float64(95784.61),
#   'zone_width': np.float64(840.3899999999994),
#   'body_size': np.float64(413.570000000007),
#   'wick_ratio': np.float64(0.5078832446840071),
#   'volume_on_creation': np.float64(979.2255),
#   'avg_volume_past_5': np.float64(811.42062),
#   'prev_volatility_5': np.float64(242.4601505732462),
#   'momentum_5': np.float64(-757.9900000000052),
#   'touch_index': None,
#   'time_frame': '1h'},
#  {'index': 26166,
#   'type': 'Bullish OB',
#   'ema 20': np.float64(96673.34256075631),
#   'ema 50': np.float64(96054.72884753943),
#   'atr': np.float64(524.6311993099023),
#   'rsi': np.float64(56.58963412105022),
#   'atr_mean': np.float64(481.67640684957513),
#   'zone_high': np.float64(97390.0),
#   'zone_low': np.float64(96978.04),
#   'zone_width': np.float64(411.9600000000064),
#   'body_size': np.float64(232.38999999999942),
#   'wick_ratio': np.float64(0.4358918341586664),
#   'volume_on_creation': np.float64(354.25476),
#   'avg_volume_past_5': np.float64(742.952834),
#   'prev_volatility_5': np.float64(385.74563688524466),
#   'momentum_5': np.float64(436.9100000000035),
#   'touch_index': None,
#   'time_frame': '1h'},
#  {'index': 26194,
#   'type': 'Bullish OB',
#   'ema 20': np.float64(101393.16345088014),
#   'ema 50': np.float64(99409.01865375057),
#   'atr': np.float64(722.247484618257),
#   'rsi': np.float64(51.60064999438048),
#   'atr_mean': np.float64(570.4573128393076),
#   'zone_high': np.float64(102800.69),
#   'zone_low': np.float64(102364.0),
#   'zone_width': np.float64(436.6900000000023),
#   'body_size': np.float64(144.4600000000064),
#   'wick_ratio': np.float64(0.6691932492156778),
#   'volume_on_creation': np.float64(887.2065),
#   'avg_volume_past_5': np.float64(959.2047660000001),
#   'prev_volatility_5': np.float64(230.61232823940796),
#   'momentum_5': np.float64(-566.9100000000035),
#   'touch_index': 26196,
#   'time_frame': '1h'},
#  {'index': 26198,
#   'type': 'Bearish OB',
#   'ema 20': np.float64(101989.23351948081),
#   'ema 50': np.float64(99966.63072969746),
#   'atr': np.float64(698.7369923516779),
#   'rsi': np.float64(78.64748632315793),
#   'atr_mean': np.float64(579.740447808295),
#   'zone_high': np.float64(104361.3),
#   'zone_low': np.float64(103127.76),
#   'zone_width': np.float64(1233.5400000000081),
#   'body_size': np.float64(398.6600000000035),
#   'wick_ratio': np.float64(0.6768163172657548),
#   'volume_on_creation': np.float64(3530.712),
#   'avg_volume_past_5': np.float64(875.424248),
#   'prev_volatility_5': np.float64(275.727099212249),
#   'momentum_5': np.float64(1033.270000000004),
#   'touch_index': 26200,
#   'time_frame': '1h'},
#  {'index': 26219,
#   'type': 'Bullish OB',
#   'ema 20': np.float64(102927.77962109247),
#   'ema 50': np.float64(101721.85662328804),
#   'atr': np.float64(506.12255354619265),
#   'rsi': np.float64(56.92744050500645),
#   'atr_mean': np.float64(656.0635806369563),
#   'zone_high': np.float64(103226.25),
#   'zone_low': np.float64(103034.5),
#   'zone_width': np.float64(191.75),
#   'body_size': np.float64(73.77000000000407),
#   'wick_ratio': np.float64(0.6152803129074103),
#   'volume_on_creation': np.float64(291.5493),
#   'avg_volume_past_5': np.float64(407.71912000000003),
#   'prev_volatility_5': np.float64(129.6940437182862),
#   'momentum_5': np.float64(180.4899999999907),
#   'touch_index': 26230,
#   'time_frame': '1h'},
#  {'index': 26263,
#   'type': 'Bearish OB',
#   'ema 20': np.float64(104157.54727670601),
#   'ema 50': np.float64(103643.04478014007),
#   'atr': np.float64(538.6374829292405),
#   'rsi': np.float64(63.6494416796586),
#   'atr_mean': np.float64(507.4076233286251),
#   'zone_high': np.float64(104635.48),
#   'zone_low': np.float64(104074.15),
#   'zone_width': np.float64(561.3300000000017),
#   'body_size': np.float64(469.3099999999977),
#   'wick_ratio': np.float64(0.16393208985802254),
#   'volume_on_creation': np.float64(864.57104),
#   'avg_volume_past_5': np.float64(462.28118200000006),
#   'prev_volatility_5': np.float64(222.1794037799194),
#   'momentum_5': np.float64(167.30999999999767),
#   'touch_index': 26265,
#   'time_frame': '1h'},
#  {'index': 26268,
#   'type': 'Bullish OB',
#   'ema 20': np.float64(104094.80069890645),
#   'ema 50': np.float64(103707.26382680879),
#   'atr': np.float64(540.936757952875),
#   'rsi': np.float64(41.9594054400863),
#   'atr_mean': np.float64(507.24175792518565),
#   'zone_high': np.float64(104072.71),
#   'zone_low': np.float64(103750.0),
#   'zone_width': np.float64(322.7100000000064),
#   'body_size': np.float64(132.6999999999971),
#   'wick_ratio': np.float64(0.5887948932478249),
#   'volume_on_creation': np.float64(459.15466),
#   'avg_volume_past_5': np.float64(899.464068),
#   'prev_volatility_5': np.float64(242.55960133542334),
#   'momentum_5': np.float64(-647.3099999999977),
#   'touch_index': 26274,
#   'time_frame': '1h'},
#  {'index': 26276,
#   'type': 'Bearish OB',
#   'ema 20': np.float64(104188.9404580218),
#   'ema 50': np.float64(103866.1822761542),
#   'atr': np.float64(629.985210228949),
#   'rsi': np.float64(55.073524370151354),
#   'atr_mean': np.float64(524.9850565808215),
#   'zone_high': np.float64(104629.96),
#   'zone_low': np.float64(103675.57),
#   'zone_width': np.float64(954.3899999999994),
#   'body_size': np.float64(438.8500000000058),
#   'wick_ratio': np.float64(0.5401774955730823),
#   'volume_on_creation': np.float64(1481.2356),
#   'avg_volume_past_5': np.float64(1149.34744),
#   'prev_volatility_5': np.float64(354.043232840285),
#   'momentum_5': np.float64(-294.04999999998836),
#   'touch_index': 26298,
#   'time_frame': '1h'}]

# %%
ob_res = check_ob_reactions(df,obs)
ob_res

# %%
import seaborn as sns
import matplotlib.pyplot as plt
def analysis_on_structure(result):
    df = pd.DataFrame(result)
    print(df['reaction_type'].value_counts())
    mean_by_reaction = df.groupby('reaction_type')[[
         'price_retrace_ratio', 'volume_on_entry',
        'time_to_entry', 'bounce_after_candles', 'max_price_move'
    ]].mean()

    print(mean_by_reaction)
    success = df['reaction_type'].isin(['clean bounce', 'bounce + break'])
    success_rate = success.sum() / len(df)

    print(f"Success rate: {success_rate:.2%}")
    print("Average time to entry:", df['time_to_entry'].mean())
    print("Average price retrace ratio:", df['price_retrace_ratio'].mean())
    bounce_moves = df[df['bounced'] == True]['max_price_move'].mean()
    violation_count = df[df['violated'] == True].shape[0]

    print("Average max price move after bounce:", bounce_moves)
    print("Number of violated :", violation_count)

    sns.boxplot(x='reaction_type', y='max_price_move', data=df)
    plt.xticks(rotation=45)
    plt.title("Max Price Move by Reaction Type")
    plt.show()

# %%
analysis_on_structure(ob_res)

# %%
analysis_on_structure(fvg_res)

# %%
df.iloc[4533]

# %% [markdown]
# SMC Structure Detection(BOS/CHOCH)

# %%
def detect_swings(df, window=20):
    swings = []

    for i in range(0, len(df)):

        if(i < window):
            high_window = df['high'].iloc[i:i + window + 1]
            low_window = df['low'].iloc[i:i + window + 1]
        elif(i+window >= len(df)):
            high_window = df['high'].iloc[i - window:]
            low_window = df['low'].iloc[i - window:]
        else:
            high_window = df['high'].iloc[i - window:i + window + 1]
            low_window = df['low'].iloc[i - window:i + window + 1]

        center_high = df['high'].iloc[i]
        center_low = df['low'].iloc[i]

        is_swing_high = center_high == high_window.max()
        is_swing_low = center_low == low_window.min()

        if is_swing_high:
            swings.append({'index': i, 'Type': 'Swing High', 'Price': center_high,'swing_strength':window,
                        'ema 20' : df.iloc[i]['ema20'],
                        'ema 50' : df.iloc[i]['ema50'],
                        'atr' : df.iloc[i]['atr'],
                        'rsi' : df.iloc[i]['rsi'],
                        'atr_mean' : df.iloc[i]['atr_mean']})
        elif is_swing_low:
            swings.append({'index': i, 'Type': 'Swing Low', 'Price': center_low,'swing_strength':window,
                        'ema 20' : df.iloc[i]['ema20'],
                        'ema 50' : df.iloc[i]['ema50'],
                        'atr' : df.iloc[i]['atr'],
                        'rsi' : df.iloc[i]['rsi'],
                        'atr_mean' : df.iloc[i]['atr_mean']})

    return swings


def label_structure_from_swings(swings):
    labeled_swings = []
    last_high = None
    last_low = None
    trend = None

    for s in swings:
        idx = s['index']
        stype = s['Type']
        price = s['Price']
        label = None

        if stype == 'Swing High':
            label = 'HH' if last_high is None or price > last_high else 'LH'
            last_high = price
        elif stype == 'Swing Low':
            label = 'HL' if last_low is None or price > last_low else 'LL'
            last_low = price

        trend = 'Bullish' if label == 'HH' else ('Bearish' if label == 'LL' else trend)

        labeled_swings.append({
            'index': idx,
            'swing_type': stype,
            'price': price,
            'structure_label': label,
            'trend': trend
        })

    return labeled_swings


def lookahead_bos_choch(labeled_swings, df, lookahead=20):
    results = []
    current_trend = None

    for s in labeled_swings:
        idx = s['index']
        label = s['structure_label']
        price = s['price']
        signal = None
        trigger_candle = None

        for j in range(1, lookahead + 1):
            if idx + j >= len(df):
                break
            close_price = df['close'].iloc[idx + j]

            if label == 'HH' and close_price > price:
                signal = 'BOS'
                current_trend = 'Bullish'
                trigger_candle = idx + j
                break

            elif label == 'LH' and close_price > price:
                signal = 'CHOCH'
                current_trend = 'Bullish'
                trigger_candle = idx + j
                break

            elif label == 'LL' and close_price < price:
                signal = 'BOS'
                current_trend = 'Bearish'
                trigger_candle = idx + j
                break

            elif label == 'HL' and close_price < price:
                signal = 'CHOCH'
                current_trend = 'Bearish'
                trigger_candle = idx + j
                break


        s['signal'] = signal
        s['trigger_candle'] = trigger_candle
        s['trend_after'] = current_trend
        results.append(s)

    return results


def extract_structure_features(df, window=20, lookahead=20):
    swings = detect_swings(df, window)
    labeled_swings = label_structure_from_swings(swings)
    structure_events = lookahead_bos_choch(labeled_swings, df, lookahead)

    features = []
    prev = None
    highest = None
    lowest = None

    for s in structure_events:
        entry = s.copy()
        entry['distance_to_prev_swing'] = s['index'] - prev['index'] if prev else None
        entry['price_change_from_last'] = s['price'] - prev['price'] if prev else None

        if s['structure_label'] in ['HH', 'LH']:
            entry['swing_strength'] = abs(s['price'] - (highest if highest is not None else s['price']))
            highest = max(highest or s['price'], s['price'])
        elif s['structure_label'] in ['LL', 'HL']:
            entry['swing_strength'] = abs(s['price'] - (lowest if lowest is not None else s['price']))
            lowest = min(lowest or s['price'], s['price'])
        else:
            entry['swing_strength'] = None

        entry['is_extreme'] = (
            (s['trend'] == 'Bullish' and s['price'] == highest) or
            (s['trend'] == 'Bearish' and s['price'] == lowest)
        )

        features.append(entry)
        prev = s

    return features

# %%
structure_feature = extract_structure_features(df,20,50)
structure_feature_df = pd.DataFrame(structure_feature)

# %%
print(structure_feature_df['signal'].value_counts())
print(structure_feature_df.groupby('signal')[['swing_strength', 'distance_to_prev_swing', 'price_change_from_last']].mean()
)
print(pd.crosstab(structure_feature_df['signal'], structure_feature_df['trend'])
)
structure_feature_df['bos_delay'] = structure_feature_df['trigger_candle'] - structure_feature_df['index']
print(structure_feature_df.groupby('signal')['bos_delay'].mean())
extreme_stats = structure_feature_df[structure_feature_df['signal'] == 'BOS'].groupby('is_extreme')['swing_strength'].mean()
print(extreme_stats)

# %% [markdown]
# SMC Structure Detection (Liquidity Zone)

# %%
def detect_liquidity_zones(df, swings, range_pct=0.01,timeframe = '1h'):
    """
    Detect buy-side and sell-side liquidity zones based on repeated highs/lows.

    Args:
        df (pd.DataFrame): OHLCV dataframe with 'high' and 'low' columns.
        swings (list): Output of detect_swings(), containing swing highs/lows.
        range_pct (float): Percent range to cluster equal highs/lows.

    Returns:
        List of liquidity zones with type, level, start/end index, and swept index.
    """
    n = len(df)
    liquidity_zones = []

    highs = [s for s in swings if s['Type'] == 'Swing High']
    lows = [s for s in swings if s['Type'] == 'Swing Low']

    pip_range = (df['high'].max() - df['low'].min()) * range_pct
    ohlc_high = df['high'].values
    ohlc_low = df['low'].values

    def process_zone(candidates, direction):
        result = []
        used = set()
        for i, base in enumerate(candidates):
            if base['index'] in used:
                continue

            base_level = base['Price']
            range_low = base_level - pip_range
            range_high = base_level + pip_range

            group = [base]
            prices = [base['Price']]
            end_idx = base['index']

            for other in candidates[i+1:]:
                if other['index'] in used:
                    continue
                if range_low <= other['Price'] <= range_high:
                    group.append(other)
                    used.add(other['index'])
                    prices.append(other['Price'])
                    end_idx = other['index']

            if len(group) < 2:
                continue  # not enough for liquidity

            avg_level = sum(prices) / len(prices)
            zone_high = avg_level + pip_range
            zone_low = avg_level - pip_range
            liquidity_height = zone_high - zone_low
            equal_level_deviation = np.std(prices)
            duration = end_idx - group[0]['index']
            swing_strengths = [g['swing_strength'] for g in group if 'swing_strength' in g]
            avg_swing_strength = np.mean(swing_strengths) if swing_strengths else None

            # Average volume around touches
            volumes = [df.iloc[g['index']]['volume'] for g in group if g['index'] < len(df)]
            avg_volume = np.mean(volumes) if volumes else None

            ema20s = [g['ema 20'] for g in group if 'ema 20' in g]
            ema50s = [g['ema 50'] for g in group if 'ema 50' in g]
            rsis = [g['rsi'] for g in group if 'rsi' in g]
            atrs = [g['atr'] for g in group if 'atr' in g]
            atr_means = [g['atr_mean'] for g in group if 'atr_mean' in g]

            # Find sweep candle
            start = end_idx + 1
            swept_index = None
            if start < n:
                if direction == 'Sell-Side':
                    cond = ohlc_high[start:] >= range_high
                else:
                    cond = ohlc_low[start:] <= range_low

                if np.any(cond):
                    swept_index = start + int(np.argmax(cond))

            result.append({
                'type': f'{direction} Liq',
                'level': avg_level,
                'zone_high': zone_high,
                'zone_low': zone_low,
                'count': len(group),
                'index' : group[0]['index'],
                'indexs': [g['index'] for g in group],
                'end_index': end_idx,
                'swept_index': swept_index,
                'liquidity_height': liquidity_height,
                'equal_level_deviation': equal_level_deviation,
                'avg_volume_around_zone': avg_volume,
                'duration_between_first_last_touch': duration,
                'avg_swing_strength': avg_swing_strength,
                'avg_ema_20' : np.mean(ema20s),
                'avg_ema_50' : np.mean(ema50s),
                'avg_rsi' : np.mean(rsis),
                'avg_atr' : np.mean(atrs),
                'avg_atr_mean' : np.mean(atr_means),
                'time_frame' : timeframe,
            })


        return result

    buy_side = process_zone(lows, 'Buy-Side')
    sell_side = process_zone(highs, 'Sell-Side')

    return buy_side + sell_side

# %%
def get_liq_touches(df, liquidity_zones):
    lows = df['low'].values
    highs = df['high'].values
    opens = df['open'].values

    results = []
    for zone in liquidity_zones:
        zone_high = zone['zone_high']
        zone_low = zone['zone_low']
        start_idx = zone['index'] + 2
        end_idx = zone['end_index'] - 2

        touches = []
        for i in range(start_idx, min(end_idx, len(df))):
            low = lows[i]
            high = highs[i]
            open_price = opens[i]

            if (high >= zone_low and open_price < zone_low) or (open_price > zone_high and low <= zone_high):
                touches.append(i)

        results.append({**zone, 'touch_indexs': touches})

    return results

# %%
swings = detect_swings(df, 15)
liquidity = detect_liquidity_zones(df,swings)
liquidity

# %%
def check_liquidity_reactions_on_touches(df, liquidity_zones, lookahead=24, max_touches=5):
    results = []

    for zone in liquidity_zones:
        zone_high = zone['zone_high']
        zone_low = zone['zone_low']
        ltype = zone['type']

        touches = []
        touch_count = 0
        start = zone['start_index']

        for i in range(zone['start_index'] + 1, len(df)):
            low = df['low'].iloc[i]
            high = df['high'].iloc[i]
            volume = df['volume'].iloc[i]
            open_price = df['open'].iloc[i]

            if (high >= zone_low and open_price < zone_low) or ( open_price > zone_high and low <= zone_high):
                '''if touch_count >= max_touches:
                    break'''
                touch_index = i
                touch_result = {
                    'touch_index': touch_index,
                    'touch_volume' : volume,
                    'time_to_entry' : start - i,
                    'reaction_type': 'neutral',
                    'bounced': False,
                    'violated': False,
                    'price_move_after_touch': None
                }

                if touch_index + lookahead < len(df):
                    future = df.iloc[touch_index + 1 : touch_index + 1 + lookahead]

                    if ltype == 'Buy-Side Liq':
                        if any(future['close'] < zone_low):
                            touch_result['reaction_type'] = 'violation'
                            touch_result['violated'] = True
                        elif any(future['close'] > df['close'].iloc[touch_index]):
                            touch_result['reaction_type'] = 'bounce'
                            touch_result['bounced'] = True
                        else:
                            touch_result['reaction_type'] = 'neutral'
                        touch_result['price_move_after_touch'] = future['high'].max() - df['high'].iloc[touch_index]

                    elif ltype == 'Sell-Side Liq':
                        if any(future['close'] > zone_high):
                            touch_result['reaction_type'] = 'violation'
                            touch_result['violated'] = True
                        elif any(future['close'] < df['close'].iloc[touch_index]):
                            touch_result['reaction_type'] = 'bounce'
                            touch_result['bounced'] = True
                        else:
                            touch_result['reaction_type'] = 'neutral'
                        touch_result['price_move_after_touch'] = df['low'].iloc[touch_index] - future['low'].min()

                touches.append(touch_result)
                touch_count += 1
                start = i

        results.append({
            **zone,
            'touch_count': len(touches),
            'touches': touches
        })

    return results

# %%
liq_res = check_liquidity_reactions_on_touches(df,liquidity)
liq_res
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-5a0c719f381e> in <cell line: 0>()
# ----> 1 liq_res = check_liquidity_reactions_on_touches(df,liquidity)
#       2 liq_res
#
# NameError: name 'liquidity' is not defined

# %%
def add_distance_to_nearest_zones_above_below(zones, threshold=0.1):
    """
    Adds the nearest zone above and below the current zone based on mid-price distance.
    Each zone must have: 'zone_high', 'zone_low', 'type', and either 'index' or 'start_index'.
    """
    updated_zones = []

    for i, zone in enumerate(zones):
        this_mid = (zone['zone_high'] + zone['zone_low']) / 2

        if zone['type'] in ['Sell-Side Liq','Buy-Side Liq']:
          for index in zone['touch_indexs']:

            min_dist_above = float('inf')
            min_dist_below = float('inf')

            nearest_above_type = None
            nearest_below_type = None
            nearest_above_zone = None
            nearest_below_zone = None
            nearest_above_index = None
            nearest_below_index = None
            h1=None
            h2=None
            l1=None
            l2=None

            valid_zones = [
        z for z in zones
        if z.get('touch_index') is None or z.get('touch_index') > index or (z.get('swept_index',0) > index)
    ]


            for j, other in enumerate(valid_zones):
                if i == j:
                    continue

                other_mid = (other['zone_high'] + other['zone_low']) / 2
                dist = abs(this_mid - other_mid)
                if dist > (this_mid * threshold):
                    continue

                if other_mid > this_mid and dist < min_dist_above:
                    min_dist_above = dist
                    nearest_above_zone = other

                elif other_mid < this_mid and dist < min_dist_below:
                    min_dist_below = dist
                    nearest_below_zone = other

            updated = zone.copy()
            updated['distance_to_nearest_zone_above'] = min_dist_above
            updated['nearest_zone_above'] = nearest_above_zone

            updated['distance_to_nearest_zone_below'] = min_dist_below
            updated['nearest_zone_below'] = nearest_below_zone
            updated['liq_touch_idx'] = index

            #updated['valid_zones'] = valid_zones

            updated_zones.append(updated)

        else:

          min_dist_above = float('inf')
          min_dist_below = float('inf')

          nearest_above_type = None
          nearest_below_type = None
          nearest_above_zone = None
          nearest_below_zone = None
          nearest_above_index = None
          nearest_below_index = None
          h1=None
          h2=None
          l1=None
          l2=None

          valid_zones = [
      z for z in zones
      if z.get('touch_index') is None or z.get('touch_index') > zone.get('index', 0) or (z.get('swept_index',0) > zone.get('index',0))
  ]


          for j, other in enumerate(valid_zones):
              if i == j:
                  continue

              other_mid = (other['zone_high'] + other['zone_low']) / 2
              dist = abs(this_mid - other_mid)
              if dist > (this_mid * threshold):
                  continue

              if other_mid > this_mid and dist < min_dist_above:
                  min_dist_above = dist
                  nearest_above_zone = other

              elif other_mid < this_mid and dist < min_dist_below:
                  min_dist_below = dist
                  nearest_below_zone = other

          updated = zone.copy()
          updated['distance_to_nearest_zone_above'] = min_dist_above
          updated['nearest_zone_above'] = nearest_above_zone

          updated['distance_to_nearest_zone_below'] = min_dist_below
          updated['nearest_zone_below'] = nearest_below_zone

          #updated['valid_zones'] = valid_zones

          updated_zones.append(updated)

    return updated_zones

# %%
fvg = detect_fvg(df)
ob = detect_order_blocks(df,0.3)
swings = detect_swings(df,15)
liq = detect_liquidity_zones(df,swings)
liq = get_liq_touches(df,liq)

# %%
all_zones = fvg+ob+liq
all_zones = add_distance_to_nearest_zones_above_below(all_zones)

# %%
all_zones = sorted(all_zones,key = lambda x : x['index'])

# %%
all_zones[-1]
# Out:
# {'index': 26296,
#  'type': 'Bullish FVG',
#  'ema 20': np.float64(102797.92402336992),
#  'ema 50': np.float64(103130.61325277487),
#  'atr': np.float64(686.54022866331),
#  'rsi': np.float64(75.60627550186999),
#  'atr_mean': np.float64(630.9504022425516),
#  'zone_high': np.float64(103273.84),
#  'zone_low': np.float64(102958.81),
#  'zone_width': np.float64(315.02999999999884),
#  'body_size': np.float64(735.0299999999988),
#  'wick_ratio': np.float64(0.06863912823111817),
#  'volume_on_creation': np.float64(997.6213),
#  'avg_volume_past_5': np.float64(824.3582700000001),
#  'prev_volatility_5': 114.59670880963736,
#  'momentum_5': np.float64(711.3199999999924),
#  'touch_index': 26301,
#  'distance_to_nearest_zone_above': np.float64(1036.4400000000169),
#  'nearest_zone_type_above': 'Bearish OB',
#  'nearest_zone_index_above': 26276,
#  'nearest_above_zone_high': np.float64(104629.96),
#  'nearest_above_zone_low': np.float64(103675.57),
#  'distance_to_nearest_zone_below': np.float64(819.9799999999959),
#  'nearest_zone_type_below': 'Buy-Side Liq',
#  'nearest_zone_index_below': 23535,
#  'nearest_below_zone_high': np.float64(103237.465),
#  'nearest_below_zone_low': np.float64(101355.225)}

# %%
all_zones_reactions = check_fvg_reactions(df,fvg) + check_ob_reactions(df,ob) + check_liquidity_reactions_on_touches(df,liq)

# %%
all_zones_reactions = add_distance_to_nearest_zones_above_below(all_zones_reactions)
# Out:
# Buy-Side Liq
# 15503
# Buy-Side Liq
# 13952
# Buy-Side Liq
# 21983
# Sell-Side Liq
# 22854

# %%
df_zone_reaction = pd.DataFrame(all_zones_reactions)
df_zone_reaction.head()
# Out:
#    index         type  zone_high  zone_low  zone_width  body_size  wick_ratio  \
# 0   36.0  Bullish FVG   31810.60  31350.00      460.60     608.41    0.217237
# 1   71.0  Bearish FVG   30783.74  30380.00      403.74     650.42    0.297056
# 2   83.0  Bearish FVG   28367.07  27867.97      499.10     612.53    0.551490
# 3  171.0  Bullish FVG   30858.01  30500.00      358.01     600.31    0.272157
# 4  181.0  Bearish FVG   30250.01  29741.28      508.73     712.81    0.220905
#
#    volume_on_creation  avg_volume_past_5  prev_volatility_5  ...  start_index  \
# 0           8317.6280         9936.27840         221.851728  ...          NaN
# 1           5657.9210        17141.60650         972.892652  ...          NaN
# 2          18762.4550         6467.05250         527.668683  ...          NaN
# 3           5900.3486         1608.62296         198.806311  ...          NaN
# 4           6918.5150         2141.73548         202.457855  ...          NaN
#
#   end_index swept_index liquidity_height equal_level_deviation  \
# 0       NaN         NaN              NaN                   NaN
# 1       NaN         NaN              NaN                   NaN
# 2       NaN         NaN              NaN                   NaN
# 3       NaN         NaN              NaN                   NaN
# 4       NaN         NaN              NaN                   NaN
#
#    avg_volume_around_zone  duration_between_first_last_touch  \
# 0                     NaN                                NaN
# 1                     NaN                                NaN
# 2                     NaN                                NaN
# 3                     NaN                                NaN
# 4                     NaN                                NaN
#
#    avg_swing_strength  touch_count  touches
# 0                 NaN          NaN      NaN
# 1                 NaN          NaN      NaN
# 2                 NaN          NaN      NaN
# 3                 NaN          NaN      NaN
# 4                 NaN          NaN      NaN
#
# [5 rows x 38 columns]

# %%
df_zone_reaction.columns
# Out:
# Index(['index', 'type', 'zone_high', 'zone_low', 'zone_width', 'body_size',
#        'wick_ratio', 'volume_on_creation', 'avg_volume_past_5',
#        'prev_volatility_5', 'momentum_5', 'time_to_entry', 'volume_on_entry',
#        'reaction_type', 'distance_to_nearest_zone', 'nearest_zone_type',
#        'nearest_zone_index', 'level', 'equal_level_deviation',
#        'avg_volume_around_zone', 'duration_between_first_last_touch'],
#       dtype='object')

# %%
df_zone_reaction = df_zone_reaction.drop(columns=['entered',
'partial_mitigated',
'bounced',
'violated',
'price_retrace_ratio',
'bounce_after_candles',
'violated_after_candles','violated_after_candle','liquidity_height','avg_swing_strength',
'max_price_move'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-f0293763f77a> in <cell line: 0>()
# ----> 1 df_zone_reaction = df_zone_reaction.drop(columns=['entered',
#       2 'partial_mitigated',
#       3 'bounced',
#       4 'violated',
#       5 'price_retrace_ratio',
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4828                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4829             else:
# -> 4830                 new_axis = axis.drop(labels, errors=errors)
#    4831             indexer = axis.get_indexer(new_axis)
#    4832
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    7068         if mask.any():
#    7069             if errors != "ignore":
# -> 7070                 raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071             indexer = indexer[~mask]
#    7072         return self.delete(indexer)
#
# KeyError: "['entered', 'partial_mitigated', 'bounced', 'violated', 'price_retrace_ratio', 'bounce_after_candles', 'violated_after_candles', 'violated_after_candle', 'liquidity_height', 'avg_swing_strength', 'max_price_move'] not found in axis"

# %%
df_zone_reaction.loc[df_zone_reaction['start_index'].notna(),'index'] = df_zone_reaction.loc[df_zone_reaction['start_index'].notna(),'index'].fillna(df_zone_reaction['start_index'])

# %%
df_zone_reaction = df_zone_reaction.drop(columns=['start_index','end_index','swept_index','count','touch_count'])

# %%
def flatten_zone_reaction_row(row):
    """
    Flattens a single liquidity zone row into multiple rows based on touches.

    Args:
        row (pd.Series): A row from a DataFrame containing a 'touches' column with list of dicts.

    Returns:
        List of dicts (flattened rows).
    """
    flattened = []

    touches = row.get('touches', [])
    if not isinstance(touches, list) or len(touches) == 0:
        # Return the row as-is with no touch-specific data
        base = row.drop(labels='touches').to_dict()
        flattened.append(base)
        return flattened

    for touch in touches:
        base = row.drop(labels='touches').to_dict()
        base['reaction_type'] = touch.get('reaction_type')
        base['time_to_entry'] = touch.get('time_to_entry')
        base['volume_on_entry'] = touch.get('touch_volume')
        flattened.append(base)

    return flattened

def flatten_reaction_dataframe(df):
    """
    Apply flatten_liquidity_row to each row and combine all into a new flattened DataFrame.
    """
    all_rows = []
    for _, row in df.iterrows():
        flattened_rows = flatten_zone_reaction_row(row)
        all_rows.extend(flattened_rows)
    return pd.DataFrame(all_rows)

# %%
df_zone_reaction = flatten_reaction_dataframe(df_zone_reaction)

# %%
df_zone_reaction['level'] = df_zone_reaction['level'].fillna((df_zone_reaction['zone_high']+df_zone_reaction['zone_low'])/2)
df_zone_reaction['zone_width'] = df_zone_reaction['zone_width'].fillna(0)
df_zone_reaction['body_size'] = df_zone_reaction['body_size'].fillna(0)
df_zone_reaction['wick_ratio'] = df_zone_reaction['wick_ratio'].fillna(0)
df_zone_reaction['volume_on_creation'] = df_zone_reaction['volume_on_creation'].fillna(0)
df_zone_reaction['avg_volume_past_5'] = df_zone_reaction['avg_volume_past_5'].fillna(0)
df_zone_reaction['prev_volatility_5'] = df_zone_reaction['prev_volatility_5'].fillna(0)
df_zone_reaction['momentum_5'] = df_zone_reaction['momentum_5'].fillna(0)
df_zone_reaction['avg_volume_around_zone'] = df_zone_reaction['avg_volume_around_zone'].fillna(0)
df_zone_reaction['equal_level_deviation'] = df_zone_reaction['equal_level_deviation'].fillna(0)
df_zone_reaction['duration_between_first_last_touch'] = df_zone_reaction['duration_between_first_last_touch'].fillna(0)

# %%
df_zone_reaction['type'].unique()
# Out:
# array(['Bullish FVG', 'Bearish FVG', 'Bearish OB', 'Bullish OB',
#        'Buy-Side Liq', 'Sell-Side Liq'], dtype=object)

# %%
df_zone_reaction.to_csv('reactions.csv',index=False)

# %%
df_zone_reaction.describe()
# Out:
#                 open           high            low          close  \
# count   26303.000000   26303.000000   26303.000000   26303.000000
# mean    46921.543362   47094.190026   46745.079713   46924.088932
# std     26488.195214   26589.843945   26385.715766   26490.205881
# min     15648.230000   15769.990000   15476.000000   15649.520000
# 25%     24763.430000   24885.220000   24641.380000   24764.085000
# 50%     35306.610000   35419.290000   35214.390000   35310.340000
# 75%     66472.600000   66704.035000   66200.000000   66474.620000
# max    108320.000000  109588.000000  107780.510000  108320.010000
#
#               volume
# count   26303.000000
# mean     3828.297420
# std      5733.081096
# min         0.000000
# 25%       757.743230
# 50%      1502.657300
# 75%      4624.191150
# max    137207.190000

# %%
df_zone_reaction.notna().sum()
# Out:
# index                                11246
# type                                 11246
# zone_high                            11246
# zone_low                             11246
# zone_width                           11246
# body_size                            11246
# wick_ratio                           11246
# volume_on_creation                   11246
# avg_volume_past_5                    11246
# prev_volatility_5                    11246
# momentum_5                           11246
# time_to_entry                        10921
# volume_on_entry                      10921
# reaction_type                        11246
# distance_to_nearest_zone             11246
# nearest_zone_type                    11243
# nearest_zone_index                   11243
# level                                11246
# equal_level_deviation                11246
# avg_volume_around_zone               11246
# duration_between_first_last_touch    11246
# dtype: int64

# %%
df_zone_reaction= df_zone_reaction.dropna()

# %%
df_ob_fvg_reaction = df_zone_reaction.loc[~df_zone_reaction['type'].isin(['Buy-Side Liq','Sell-Side Liq'])]
df_liq_reaction = df_zone_reaction.loc[df_zone_reaction['type'] .isin(['Buy-Sidde Liq','Sell-Side Liq'])]

# %%
reaction_type1 = list(df_ob_fvg_reaction.reaction_type.unique())
reaction_type2 = list(df_liq_reaction.reaction_type.unique())
zone_type = list(df_zone_reaction['type'].unique())

# %%
df_ob_fvg_reaction['type'] = df_ob_fvg_reaction['type'].apply(lambda x : zone_type.index(x))
df_ob_fvg_reaction['nearest_zone_type'] = df_ob_fvg_reaction['nearest_zone_type'].apply(lambda x : zone_type.index(x))
df_liq_reaction['type'] = df_liq_reaction['type'].apply(lambda x : zone_type.index(x))
df_liq_reaction['nearest_zone_type'] = df_liq_reaction['nearest_zone_type'].apply(lambda x : zone_type.index(x))
# Out:
# <ipython-input-44-049bf4e42cea>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ob_fvg_reaction['type'] = df_ob_fvg_reaction['type'].apply(lambda x : zone_type.index(x))
# <ipython-input-44-049bf4e42cea>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ob_fvg_reaction['nearest_zone_type'] = df_ob_fvg_reaction['nearest_zone_type'].apply(lambda x : zone_type.index(x))
# <ipython-input-44-049bf4e42cea>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_liq_reaction['type'] = df_liq_reaction['type'].apply(lambda x : zone_type.index(x))
# <ipython-input-44-049bf4e42cea>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_liq_reaction['nearest_zone_type'] = df_liq_reaction['nearest_zone_type'].apply(lambda x : zone_type.index(x))

# %%
df_ob_fvg_reaction['reaction_type'] = df_ob_fvg_reaction['reaction_type'].apply(lambda x : reaction_type1.index(x))
df_liq_reaction['reaction_type'] = df_liq_reaction['reaction_type'].apply(lambda x : reaction_type2.index(x))
# Out:
# <ipython-input-45-acef5023f9a4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ob_fvg_reaction['reaction_type'] = df_ob_fvg_reaction['reaction_type'].apply(lambda x : reaction_type1.index(x))
# <ipython-input-45-acef5023f9a4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_liq_reaction['reaction_type'] = df_liq_reaction['reaction_type'].apply(lambda x : reaction_type2.index(x))

# %%
df_zone_reaction.dtypes
# Out:
# index                                float64
# type                                  object
# zone_high                            float64
# zone_low                             float64
# zone_width                           float64
# body_size                            float64
# wick_ratio                           float64
# volume_on_creation                   float64
# avg_volume_past_5                    float64
# prev_volatility_5                    float64
# momentum_5                           float64
# time_to_entry                        float64
# volume_on_entry                      float64
# reaction_type                         object
# distance_to_nearest_zone             float64
# nearest_zone_type                     object
# nearest_zone_index                   float64
# level                                float64
# equal_level_deviation                float64
# avg_volume_around_zone               float64
# duration_between_first_last_touch    float64
# dtype: object

# %%
X1 = df_liq_reaction.drop(columns=['reaction_type','nearest_zone_index','index','zone_high','zone_low','duration_between_first_last_touch'])
Y1 = df_liq_reaction['reaction_type']
X2 = df_ob_fvg_reaction.drop(columns=['reaction_type','nearest_zone_index','index','zone_high','zone_low','duration_between_first_last_touch'])
Y2 = df_ob_fvg_reaction['reaction_type']

# %%
from sklearn.model_selection import train_test_split

train_x1,val_x1,train_y1,val_y1 = train_test_split(X1,Y1,test_size=0.7)
train_x2,val_x2,train_y2,val_y2 = train_test_split(X2,Y2,test_size=0.7)

# %%
from xgboost import XGBClassifier

liq_model = XGBClassifier(
    n_estimators=150,
    max_depth=6,
    learning_rate=0.05,
    random_state=42,
    use_label_encoder=False,
    eval_metric='logloss'
)
ob_fvg_model = XGBClassifier(
    n_estimators=150,
    max_depth=6,
    learning_rate=0.05,
    random_state=42,
    use_label_encoder=False,
    eval_metric='logloss'
)
liq_model.fit(train_x1, train_y1)
ob_fvg_model.fit(train_x2,train_y2)
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [04:27:19] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [04:27:20] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=150,
#               n_jobs=None, num_parallel_tree=None, objective='multi:softprob', ...)

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

# After training
y_pred1 = liq_model.predict(val_x1)
y_pred2 = ob_fvg_model.predict(val_x2)

print(classification_report(val_y1, y_pred1))
print(classification_report(val_y2, y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.58      0.66      0.62      1558
#            1       0.62      0.59      0.60      1584
#            2       0.00      0.00      0.00       125
#
#     accuracy                           0.60      3267
#    macro avg       0.40      0.42      0.41      3267
# weighted avg       0.58      0.60      0.59      3267
#
#               precision    recall  f1-score   support
#
#            0       0.47      0.51      0.49       437
#            1       0.33      0.18      0.23       137
#            2       0.43      0.45      0.44       377
#            3       0.10      0.14      0.12         7
#
#     accuracy                           0.44       958
#    macro avg       0.33      0.32      0.32       958
# weighted avg       0.43      0.44      0.43       958

# %%
print(X2.columns)
print(X1.columns)
# Out:
# Index(['type', 'zone_width', 'body_size', 'wick_ratio', 'volume_on_creation',
#        'avg_volume_past_5', 'prev_volatility_5', 'momentum_5',
#        'distance_to_nearest_zone', 'nearest_zone_type', 'level',
#        'equal_level_deviation', 'avg_volume_around_zone'],
#       dtype='object')
# Index(['type', 'zone_width', 'body_size', 'wick_ratio', 'volume_on_creation',
#        'avg_volume_past_5', 'prev_volatility_5', 'momentum_5',
#        'distance_to_nearest_zone', 'nearest_zone_type', 'level',
#        'equal_level_deviation', 'avg_volume_around_zone'],
#       dtype='object')

# %%
def label_direction_based_on_zone_touch(df, fvg, ob, liq,  threshold=0.25):
    labels = []
    df = df.reset_index(drop=True)
    n = len(df)

    all_zones = []

    for zone_list, zone_type in [(fvg, 'FVG'), (ob, 'OB'), (liq, 'LIQ')]:
        for z in zone_list:
            if 'zone_high' not in z:
                z['zone_high'] = z.get('zone_high', z.get('Price', 0) + 0.001)
            if 'zone_low' not in z:
                z['zone_low'] = z.get('zone_low', z.get('Price', 0) - 0.001)
            z['zone_type'] = zone_type if not (zone_type== 'Swing') else z['Type']
            z['mid_price'] = (z['zone_high'] + z['zone_low']) / 2
            z['index'] = z.get('index', z.get('start_index'))
            if z['index'] is not None:
                all_zones.append(z)

    used_indx = set()
    i = 0
    while i < n:
        print(f"Processing candle {i+1}/{n}", end='\r')
        curr_price = df.loc[i, 'close']

        # Filter past zones once per i
        past_zones = [
            z for z in all_zones
            if z['index'] < i and (z['zone_high'], z['zone_low'], z['zone_type']) not in used_indx
            and abs(z['mid_price'] - curr_price) < curr_price*threshold
            or (z['zone_type'] == 'LIQ' and not z['swept_index']==None and z['swept_index']>i and z['index'] < i and abs(z['mid_price'] - curr_price) < curr_price*threshold)
        ]

        if not past_zones:
            labels.append({
                'index': i,
                'candle detail': df.iloc[i].to_dict(),
                'direction': None,
                'touched_index' : None,
                'touched_zone_type': None,
                'target_zone_index': None,
                'zone_detail' : None,
                'past_zones' : None
            })
            i += 1
            continue

        touched_zone = None
        touched_index = None

        for zone in past_zones:
            z_high = zone['zone_high']
            z_low = zone['zone_low']

            # Use slicing and vectorized comparison instead of for-loop
            future_slice = df.iloc[i+1:]
            condition = ((future_slice['low'] <= z_high) & (future_slice['open'] > z_high)) | ((future_slice['open'] < z_low) & (future_slice['high'] >= z_low))
            match = future_slice[condition]

            if not match.empty:
                touched_index = match.index[0]
                touched_zone = zone
                if(touched_zone['zone_type'] in ['FVG','Swing High','Swing Low','OB']):
                    used_indx.add((zone['zone_high'], zone['zone_low'], zone['zone_type']))


        if touched_zone and touched_index:
            price_slice = df.loc[i:touched_index - 1].copy()
            zone_mid = touched_zone['mid_price']
            direction_series = np.where(zone_mid > price_slice['close'], 'long', 'short')

            # Build labels all at once
            for j, (idx, row) in enumerate(price_slice.iterrows()):
                labels.append({
                    'index': idx,
                    'candle detail': row.to_dict(),
                    'direction': direction_series[j],
                    'touched_index' : touched_index,
                    'touched_zone_type': touched_zone['zone_type'],
                    'target_zone_index': touched_zone['index'],
                    'zone_detail' : touched_zone,
                    'past_zones' : past_zones
                })

            # Advance i
            i = touched_index + 1  # skip to after the touch
        else:
            labels.append({
                'index': i,
                'candle detail': df.iloc[i].to_dict(),
                'direction': 'none',
                'touched_index' : None,
                'touched_zone_type': None,
                'target_zone_index': None,
                'zone_detail' : None,
                'past_zones' : past_zones
            })
            i += 1

    return labels

# %%
labels = label_direction_based_on_zone_touch(df,fvg,ob,liq,threshold=0.1)

# %%
# Assuming 'labels' is the result from your function
df_labels = pd.DataFrame(labels)
# Expand 'candle detail'
candle_df = pd.json_normalize(df_labels['candle detail'])

# Expand 'touched_zone_detail'
zone_df = pd.json_normalize(df_labels['zone_detail'])

# Combine with top-level fields
df_final = pd.concat([df_labels.drop(columns=['candle detail', 'zone_detail']),
                      candle_df.add_prefix('candle_'),
                      zone_df.add_prefix('zone_')],
                     axis=1)

# %%
candle_df.head()

# %%
df_final.head(10)

# %%
df_final.to_csv('direction_1h.csv',index= False)

# %%
def flatten_label_row(labeled_row):
    flat_rows = []
    current_index = labeled_row['index']
    curr_price = labeled_row['candle detail']['close']
    touched_zone = labeled_row.get('zone_detail')
    past_zones = labeled_row.get('past_zones',[])
    if not past_zones:
        return []

    for zone in labeled_row['past_zones']:
        flat_row = {
            'candle_index': current_index,
            'zone_index': zone.get('index',None),
            'zone_type': zone.get('zone_type',None),
            'zone_mid_price': float(zone['mid_price']),
            'zone_high': float(zone['zone_high']),
            'zone_low': float(zone['zone_low']),
            'zone_age': current_index - zone['index'],
            'zone_range': float(zone['zone_high']) - float(zone['zone_low']),
            'zone_mid_distance': abs(curr_price - float(zone['mid_price'])),
            'price_above_zone': (curr_price > float(zone['zone_high'])),
            'price_inside_zone': (float(zone['zone_low']) < curr_price < float(zone['zone_high'])),
            'candle_close': curr_price,
            'candle_open': labeled_row['candle detail']['open'],
            'candle_high': labeled_row['candle detail']['high'],
            'candle_low': labeled_row['candle detail']['low'],
            'touched_index': labeled_row.get('touched_index'),
            'is_target': (
                touched_zone and
                zone['index'] == touched_zone['index'] and
                zone['zone_type'] == touched_zone['zone_type'] and
                abs(zone['zone_high'] - touched_zone['zone_high']) < 1e-6 and
                abs(zone['zone_low'] - touched_zone['zone_low']) < 1e-6
            )
        }

        flat_rows.append(flat_row)

    return flat_rows

# %%
def flatten_all_rows(labeled_data):
    all_flat = []
    for row in labeled_data:
        all_flat.extend(flatten_label_row(row))
    return pd.DataFrame(all_flat)

# %%
df_past_zones = flatten_all_rows(labels)

# %%
df_past_zones = pd.read_csv('past_zone.csv')

# %%
df_past_zones = df_past_zones.dropna()

# %%
zone_type = list(df_past_zones['zone_type'].unique())
is_target = list(df_past_zones['is_target'].unique())
price_above_zone = list(df_past_zones['price_above_zone'].unique())
prive_inside_zone = list(df_past_zones['price_inside_zone'].unique())

# %%
df_past_zones['zone_type'] = df_past_zones['zone_type'].apply(lambda x : zone_type.index(x))
df_past_zones['is_target'] = df_past_zones['is_target'].apply(lambda x : is_target.index(x))
df_past_zones['price_above_zone'] = df_past_zones['price_above_zone'].apply(lambda x : price_above_zone.index(x))
df_past_zones['price_inside_zone'] = df_past_zones['price_inside_zone'].apply(lambda x : prive_inside_zone.index(x))

# %%
df_past_zones.columns

# %%
df_past_zones.to_csv('past_zone.csv',index=False)

# %%
df_swings = pd.DataFrame(swings)
df_swings.to_csv('swings.csv',index=False)

# %%
df_final.notna().sum()

# %%
labels[10]

# %%
for i in labels:
    if i['index'] == 13670:
        print(i)

# %%
fvg

# %%
print(labels)

# %%
df_with_labels = df_1h.join(labels, how='left')

# %%
df.iloc[17254]

# %% [markdown]
# Data Combination of SMC Elements

# %%
def smc_combine(df):
    merged = df.copy()
    merged = merged.reset_index(drop = True)
    merged['index'] = merged.index  # ensure index column exists
    fvg = detect_fvg(df)
    #fvg = check_fvg_reactions(df,fvg)
    ob = detect_order_blocks(df)
    #ob = check_ob_reactions(df,ob)
    swings = detect_swings(df,20)
    labeled_swings = label_structure_from_swings(swings)
    bos_choch=lookahead_bos_choch(labeled_swings,df,50)
    liq = detect_liquidity_zones(df,swings)
    #liq = check_liquidity_reactions(df,liq)

    fvg_df = pd.DataFrame(fvg).set_index('index')
    ob_df = pd.DataFrame(ob).set_index('index')
    bos_choch_df = pd.DataFrame(bos_choch).set_index('trigger_candle')
    labeled_swings_df = pd.DataFrame(labeled_swings).set_index('index')
    liq_df = pd.DataFrame(liq).set_index('start_index')
    merged = merged.merge(fvg_df, on='index', how='left', suffixes=('', '_fvg'))
    merged = merged.merge(ob_df, on='index', how='left', suffixes=('', '_ob'))
    merged = merged.merge(labeled_swings_df,on = 'index',how='left',suffixes=('','_swings'))
    merged = merged.merge(bos_choch_df, on='index', how='left', suffixes=('', '_bos_choch'))
    merged = merged.merge(liq_df, left_on='index', right_index=True, how='left', suffixes=('', '_liq'))
    merged['timestamp'] = df.index
    return merged

# %%
smc_15m = smc_combine(df)
smc_1hr = smc_combine(df_1h)
smc_4hr = smc_combine(df_4h)
smc_1d = smc_combine(df_1d)

# %%
def add_htf_features(base_df,htf_df,prefix):
    base_df = base_df.copy()
    htf_df = htf_df.copy()
    base_df = base_df.set_index('timestamp')
    htf_df = htf_df.set_index('timestamp')
    for feature in ['trend', 'fvg_high', 'fvg_low', 'ob_high', 'ob_low','level','swing_type']:
        if feature in htf_df.columns:
            base_df[f'{prefix}_{feature}'] = htf_df[feature].reindex(base_df.index, method='ffill')

    return base_df.reset_index()

# %%
smc_15m = add_htf_features(smc_15m, smc_1hr, prefix='1h')
smc_15m = add_htf_features(smc_15m,smc_4hr, prefix='4h')
smc_15m = add_htf_features(smc_15m, smc_1d, prefix='1d')

# %%
smc_15m.tail()

# %%
smc_4hr.tail(20)

# %%
smc_15m.to_csv('smc.csv',index=False)

# %%
train_data = pd.read_csv('smc.csv')

# --- 1. Zone Confluence ---
train_data['fvg_ob_confluence'] = (
    (train_data['type'] == train_data['type_ob']) &
    train_data['type'].notna()
).astype(int)

train_data['fvg_liq_confluence'] = (
    (train_data['type'].notna()) &
    (train_data['type_liq'].notna()) &
    (abs(train_data['level'] - train_data['low']) < 1000)
).astype(int)

train_data['ob_liq_confluence'] = (
    (train_data['type_ob'].notna()) &
    (train_data['type_liq'].notna()) &
    (abs(train_data['level'] - train_data['low']) < 1000)
).astype(int)

# --- 2. Timing Features ---
train_data['time_since_bos_choch'] = train_data['index'] - train_data['trigger_candle']
train_data['delay_to_liquidity_sweep'] = train_data['swept_index'] - train_data['index']

# --- 3. Reaction Strengths ---
train_data['avg_max_price_move'] = train_data[[
    'max_price_move',
    'max_price_move_ob',
    'max_price_move_liq'
]].mean(axis=1)

train_data['has_strong_reaction'] = train_data['reaction_type'].isin(['clean bounce', 'bounce + break']).astype(int)

# --- 4. Labels ---
train_data['reaction_success'] = train_data['reaction_type'].isin(['clean bounce', 'bounce + break']).astype(int)
train_data['reaction_failed'] = (train_data['reaction_type'] == 'violation').astype(int)

train_data['setup_success'] = (
    (train_data['reaction_type_ob'].isin(['clean bounce'])) |
    (train_data['reaction_type'].isin(['clean bounce'])) |
    (train_data['reaction_type_liq'].isin(['clean bounce']))
).astype(int)

# Show the newly added features
train_data.tail()

# %%
drop_cols = [
    'timestamp', 'index', 'price', 'trigger_candle', 'price_bos_choch',
    'trend_bos_choch', 'signal_bos_choch', 'trend_after_bos_choch','reaction_type',
    'reaction_type_ob',
    'reaction_type_liq','has_strong_reaction',
       'reaction_success', 'reaction_failed','price_retrace_ratio','max_price_move','price_retrace_ratio_ob',
       'max_price_move_ob','max_price_move_liq','avg_max_price_move','bounced','partial_mitigated','bounced_ob'
       ,'partial_mitigated_ob','bounced_liq' ,'violated','violated_ob','violated_liq'
]

# %%
train_data.fillna({
    'structure_label': 'None',
    'signal': 'None',
    'trend': 'Unknown',

    'swing_type': 'None',
    'type': 'None',
    'type_ob': 'None',
    'type_liq': 'None'
}, inplace=True)

# Fill numeric NaNs
train_data.fillna(0, inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

categorical_cols = [
    'structure_label', 'signal', 'trend',
    'swing_type', 'type', 'type_ob', 'type_liq'
]

le = LabelEncoder()
for col in categorical_cols:
    train_data[col] = le.fit_transform(train_data[col].astype(str))

# %%
X = df_past_zones.drop(columns=['reaction_type','index','zone_high','zone_low'])
Y = df_past_zones['reaction_type']

# %%
X = df_past_zones.drop(columns=['is_target','candle_index','zone_index','touched_index','zone_type'])
Y = df_past_zones['is_target']

# %%
X = X.reset_index(drop= True)

# %%
from sklearn.preprocessing import LabelEncoder

# Encode all object columns
for col in X.columns:
    if X[col].dtype == 'object':
        X[col] = LabelEncoder().fit_transform(X[col].astype(str))

# Cast entire DataFrame to float32
X = X.astype('float32')

# %%
# Ensure all features are either int or float
cols = list(X.columns)
cols

# %%
correlations = df_zone_reaction.corr()['reaction_type'].sort_values(ascending=False)
print(correlations)
# Out:
# reaction_type                        1.000000
# type                                 0.634995
# equal_level_deviation                0.560054
# avg_volume_around_zone               0.536750
# duration_between_first_last_touch    0.405755
# nearest_zone_type                    0.133710
# nearest_zone_index                   0.045197
# zone_high                            0.010547
# level                                0.003088
# zone_low                            -0.004390
# momentum_5                          -0.039471
# index                               -0.085783
# distance_to_nearest_zone            -0.173634
# body_size                           -0.460371
# volume_on_creation                  -0.499614
# prev_volatility_5                   -0.508143
# zone_width                          -0.589860
# avg_volume_past_5                   -0.599502
# wick_ratio                          -0.643255
# Name: reaction_type, dtype: float64

# %%
from sklearn.model_selection import train_test_split

train_x,val_x,train_y,val_y = train_test_split(X,Y,test_size=0.7)

# %%
val_x.tail(5)
# Out:
#       type  zone_width   body_size  wick_ratio  volume_on_creation  \
# 1154     3   367.28125  161.867188    0.559283          630.803711
# 3897     4     0.00000    0.000000    0.000000            0.000000
# 8935     5     0.00000    0.000000    0.000000            0.000000
# 5321     4     0.00000    0.000000    0.000000            0.000000
# 6574     5     0.00000    0.000000    0.000000            0.000000
#
#       avg_volume_past_5  prev_volatility_5  momentum_5  \
# 1154         452.552063         240.957581  374.820312
# 3897           0.000000           0.000000    0.000000
# 8935           0.000000           0.000000    0.000000
# 5321           0.000000           0.000000    0.000000
# 6574           0.000000           0.000000    0.000000
#
#       distance_to_nearest_zone  nearest_zone_type         level  \
# 1154                  8.703125                  1  96656.070312
# 3897                  7.945312                  0  85138.867188
# 8935                 12.023438                  3  95526.500000
# 5321                 32.867188                  1  83595.632812
# 6574                 21.859375                  1  69019.664062
#
#       equal_level_deviation  avg_volume_around_zone
# 1154               0.000000                0.000000
# 3897             520.360474             3242.417969
# 8935             402.834137             2669.281494
# 5321             270.092865              952.661133
# 6574             442.732300             2381.000977

# %%
from xgboost import XGBClassifier

model = XGBClassifier(
    n_estimators=150,
    max_depth=6,
    learning_rate=0.05,
    random_state=42,
    use_label_encoder=False,
    eval_metric='logloss'
)

model.fit(train_x, train_y)
# Out:
# d:\data analyst\venv\Lib\site-packages\xgboost\training.py:183: UserWarning: [21:53:32] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=150, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(
    n_estimators=150,
    max_depth=6,
    random_state=42,
)

model.fit(train_x, train_y)
# Out:
# RandomForestClassifier(max_depth=6, n_estimators=150, random_state=42)

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

# After training
y_pred = model.predict(val_x)
y_proba = model.predict_proba(val_x)[:,1]

print(classification_report(val_y, y_pred))
print("AUC:", roc_auc_score(val_y, y_proba))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.33      0.34      0.34       294
#            1       0.19      0.12      0.14       181
#            2       0.38      0.51      0.43       346
#            3       0.64      0.59      0.61      2861
#            4       0.60      0.68      0.64      2601
#            5       0.00      0.00      0.00       136
#
#     accuracy                           0.58      6419
#    macro avg       0.36      0.37      0.36      6419
# weighted avg       0.57      0.58      0.57      6419
# d:\data analyst\venv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\data analyst\venv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\data analyst\venv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[72], line 8
#       5 y_proba = model.predict_proba(val_x)[:,1]
#       7 print(classification_report(val_y, y_pred))
# ----> 8 print("AUC:", roc_auc_score(val_y, y_proba))
#
# File d:\data analyst\venv\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File d:\data analyst\venv\Lib\site-packages\sklearn\metrics\_ranking.py:633, in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr, multi_class, labels)
#     626         raise ValueError(
#     627             "Partial AUC computation not available in "
#     628             "multiclass setting, 'max_fpr' must be"
#     629             " set to `None`, received `max_fpr={0}` "
#     630             "instead".format(max_fpr)
#     631         )
#     632     if multi_class == "raise":
# --> 633         raise ValueError("multi_class must be in ('ovo', 'ovr')")
#     634     return _multiclass_roc_auc_score(
#     635         y_true, y_score, labels, multi_class, average, sample_weight
#     636     )
#     637 elif y_type == "binary":
#
# ValueError: multi_class must be in ('ovo', 'ovr')

# %%
# Get feature importance as dictionary
importance_dict = model.get_booster().get_score(importance_type='gain')  # You can also use: 'weight', 'cover', 'total_gain', 'total_cover'

# Convert to DataFrame for easier viewing
importance_df = pd.DataFrame.from_dict(importance_dict, orient='index', columns=['Importance'])
importance_df.index.name = 'Feature'
importance_df = importance_df.sort_values(by='Importance', ascending=False)

print(importance_df)
# Out:
#                           Importance
# Feature
# wick_ratio                  5.611246
# type                        3.951575
# prev_volatility_5           3.072728
# zone_width                  2.948316
# body_size                   2.928156
# avg_volume_past_5           1.685203
# volume_on_creation          1.029022
# distance_to_nearest_zone    0.978505
# avg_volume_around_zone      0.950699
# equal_level_deviation       0.926550
# momentum_5                  0.876944
# nearest_zone_type           0.776307
# level                       0.666164

# %%
reaction_type
# Out:
# ['clean bounce',
#  'no entry',
#  'bounce + break',
#  'violation',
#  'bounce',
#  'neutral']

# %%
model.feature_importances_

# %%
X.iloc[-40]

# %%
model.predict(X.iloc[-41].values.reshape(1,-1))

# %%
from joblib import dump, load


dump(model,'smcXGBoost.pkl')
print("Saved successfully")

# %%
for k in train_data.iloc[50].keys():
    print(f'{k} : {train_data.iloc[50][k]}')
